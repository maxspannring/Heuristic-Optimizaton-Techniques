# %% [markdown]
# # Selective Capacitated Fair Pickup and Delivery Problem

# %% [markdown]
# The results that you can see in this notebook were obtianed using a laptop with a 11th Gen Intel i7 CPU, running Ubuntu 24.04.2., in a python 3.13.9 environment.

# %% [markdown]
# We start by importing all necessary modules

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:16:10) [GCC 11.2.0]

# %%
from dataclasses import dataclass
import math
from random import random
from collections import deque
import csv
import time
import pandas as pd
import os, glob
from tqdm import tqdm


import matplotlib.pyplot as plt
import random
random.seed(1090)

# %% [markdown]
# ## Defining an "Instance" class
# we start by defining a "Instance" class that contains all the information we are given from an instance file. We can access the variables for each instance as attributes of our "Instance" class. This is the data strucutre our algorithms will act upon

# %%
@dataclass
class Instance:
    def __init__(self, filename: str | None = None):
        if filename is not None:
            self.load_from_file(filename)

    @staticmethod # tell python this method doesn't depend on "self"
    def read_tuple(f):
        return tuple(map(int, f.readline().split()))

    def load_from_file(self, filename):
        with open(filename) as input_file:
            params_line = input_file.readline().split(" ")
            self.n = int(params_line[0])
            self.n_k = int(params_line[1])
            self.C = int(params_line[2])
            self.gamma = int(params_line[3])
            self.rho = float(params_line[4])
            _ = input_file.readline()
            demand_line = [int(c_i) for c_i in input_file.readline().split()]
            _ = input_file.readline()
            self.depot = self.read_tuple(input_file)
            self.requests = []
            self.requests_location_array = []
            for i in range(self.n):
                pick_up = self.read_tuple(input_file)
                request = {
                    "pick_up": pick_up,
                    "drop_off": None,
                    "demand": demand_line[i],
                    "index": i + 1 # because they start with one (not zero) in the assignment
                }
                self.requests.append(request)
                self.requests_location_array.append(pick_up)
            for i in range(self.n):
                drop_off = self.read_tuple(input_file)
                self.requests[i]["drop_off"] = drop_off
                self.requests_location_array.append(drop_off)
            if input_file.readline().strip() != "":# make sure we are at the end of the file and there's no more content
                raise ValueError("Unexpected extra content at end of file")

# %%
# testing how the class works
filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
aaa = Instance()
aaa.load_from_file(filename)
aaa.depot
# Out:
# (50, 50)

# %% [markdown]
# ## Helper Functions for evaluating the performance of our algorithm

# %%
# takes two tuples representing carthesian coordinates as input
def a(u, v):
    return math.ceil(math.sqrt((u[0] - v[0])**2 + (u[1] - v[1])**2))

# takes the route as list of indices of request locations as input
def get_total_distance(instance, route):
    total_distance = 0
    current_location = instance.depot # we start at the depot
    for location_index in route:
        location_index = location_index - 1 # be careful with off-by-one errors!
        next_location = instance.requests_location_array[location_index]
        total_distance = total_distance + a(current_location, next_location)
        current_location = next_location
    total_distance = total_distance + a(current_location, instance.depot)
    return total_distance

# take a list of routes as input
def get_Jain_fairness(instance, routes):
    numerator = 0
    denominator = 0
    for route in routes:
        d = get_total_distance(instance, route)
        numerator = numerator + d
        denominator = denominator + d**2
    return numerator**2 / (instance.n_k * denominator) # I know it says n in the assignment but n_k makes more sense and its like that on wikipedia

def objective_function(instance, routes):
    value = 0
    for route in routes:
        value = value + get_total_distance(instance, route)
    value = value + instance.rho * (1 - get_Jain_fairness(instance, routes))
    return value

# used for delta evaluation later on
def delta_objective(instance, old_routes, new_routes):
    changed = []
    for i, (r_old, r_new) in enumerate(zip(old_routes, new_routes)):
        if r_old != r_new:
            changed.append(i)

    d_old = []
    d_new = []
    for i in changed:
        d_old.append(get_total_distance(instance, old_routes[i]))
        d_new.append(get_total_distance(instance, new_routes[i]))

    delta_dist = sum(d_new) - sum(d_old)

    # Old aggregated sums
    old_all_dist = []
    for r in old_routes:
        old_all_dist.append(get_total_distance(instance, r))
    old_sum = sum(old_all_dist)
    old_sum_sq = sum(d * d for d in old_all_dist)

    # New aggregated sums (update only the changed routes)
    new_all_dist = old_all_dist.copy()
    for i, idx in enumerate(changed):
        new_all_dist[idx] = d_new[i]    # replace old distance with new

    new_sum = sum(new_all_dist)
    new_sum_sq = sum(d * d for d in new_all_dist)

    fairness_old = (old_sum * old_sum) / (instance.n_k * old_sum_sq)
    fairness_new = (new_sum * new_sum) / (instance.n_k * new_sum_sq)

    delta_fairness = instance.rho * ((1 - fairness_new) - (1 - fairness_old))

    return delta_dist + delta_fairness

# %% [markdown]
# ## Visualization
# In order to get a better feeling what our algorithm is actually doing, here is a small visualization (Code generated with ChatGPT)

# %%
def plot_routes(instance, routes):
    plt.figure(figsize=(10, 10))
    plt.scatter(*instance.depot, c="black", marker="s", s=100, label="Depot")  # draw the depot

    # Draw each vehicle's route
    for i, route in enumerate(routes):
        color = f"C{i % 10}"  # use matplotlib color cycle
        x_coords = [instance.depot[0]]
        y_coords = [instance.depot[1]]

        for idx in route:
            loc = instance.requests_location_array[idx - 1]
            x_coords.append(loc[0])
            y_coords.append(loc[1])

        x_coords.append(instance.depot[0])
        y_coords.append(instance.depot[1])

        plt.plot(x_coords, y_coords, "-", color=color, label=f"Vehicle {i+1}")

        # Mark pickups (▲) and drop-offs (▼)
        for idx in route:
            loc = instance.requests_location_array[idx - 1]
            if idx <= instance.n:  # pickup
                plt.scatter(loc[0], loc[1], marker="^", color=color, s=70)
            else:  # drop-off
                plt.scatter(loc[0], loc[1], marker="v", color=color, s=70)

    # Compute metrics
    total_distance = sum(get_total_distance(instance, route) for route in routes)
    jain_score = get_Jain_fairness(instance, routes)
    obj_value = objective_function(instance, routes)

    # Add metrics to the plot
    plt.figtext(0.5, -0.01,  # x=0.5 centers it, y=-0.02 slightly below the plot
                f"Total Distance: {total_distance:.2f}    "
                f"Jain Fairness: {jain_score:.3f}    "
                f"Objective: {obj_value:.2f}",
                ha="center", fontsize=12)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.axis("equal")
    plt.show()

# %% [markdown]
# ## Subtask 1: Deterministic construction heuristic
# For our first real subtask, we are asked to develop a meaningful construction heuristic. We chose to do so based on the Nearest Neighbor Heuristic, which means we start at an arbitrary node and always go to a nearest unvisited node. This seems like a reasonable choice.
# We have to adapt this heuristic a little bit to match our specific problem, i.e. we have to take into account that we have multiple vehicles and we only need to satisfy gamma requests. So:
# ```
# For each vehicle:
#     - we look at the nearest pick up location
#     - if we still have enough capacity, we go there and pick it up
#     - if not, we go to the nearest drop of location
#     - repeat until we have gamma requests done
# ```

# %%
def nearest_neighbor_heuristic(instance):
    open_requests = instance.requests.copy()
    routes = [[] for _ in range(instance.n_k)]
    current_vehicle_location = [instance.depot for _ in range(instance.n_k)]
    current_vehicle_capacity = [0 for _ in range(instance.n_k)]
    current_vehicle_requests = [[] for _ in range(instance.n_k)]

    n_served = 0
    while n_served < instance.gamma:
        for k in range(instance.n_k):
            if not open_requests and not current_vehicle_requests[k]:
                continue #we skip this vehicle
            #print(f"lenopenreq: {len(open_requests)}")
            nearest_pick_up_location = None
            if open_requests:
                try:
                    nearest_pick_up_location = min(open_requests, key=lambda req: a(req["pick_up"], current_vehicle_location[k]))
                except ValueError: # we just don't have any open requests anymore
                    #print("no more open requests")
                    pass
            if nearest_pick_up_location is not None and (nearest_pick_up_location["demand"] + current_vehicle_capacity[k] <= instance.C):
                #print(f"PICKING UP: {nearest_pick_up_location}")
                #print(nearest_pick_up_location["demand"] + current_vehicle_capacity[k])
                current_vehicle_location[k] = nearest_pick_up_location["pick_up"] # we are driving to the new pick up location
                routes[k].append(nearest_pick_up_location["index"]) # write it down in our route list
                current_vehicle_requests[k].append(nearest_pick_up_location) # take the request
                current_vehicle_capacity[k] += nearest_pick_up_location["demand"] # use some loading capacity
                open_requests.remove(nearest_pick_up_location) # it's not an open request anymore
            elif current_vehicle_requests[k]:
                nearest_drop_off_location = min(current_vehicle_requests[k], key=lambda req: a(req["drop_off"], current_vehicle_location[k]))
                #print(f"DROPPING OFF: {nearest_drop_off_location}")
                current_vehicle_location[k] = nearest_drop_off_location["drop_off"] # driving to the drop off location
                routes[k].append(nearest_drop_off_location["index"] + instance.n) # writing down the location index in our route
                current_vehicle_requests[k].remove(nearest_drop_off_location) # not our request anymore
                current_vehicle_capacity[k] -= nearest_drop_off_location["demand"] # freeing some loading capacity
                n_served += 1 # we have succesfully completed one request!
            else:
                print("some other case occured")
    # drop off the loaded requests:
    while any(current_vehicle_requests):
        for k in range(instance.n_k):
            if current_vehicle_requests[k]:
                nearest_drop_off_location = min(current_vehicle_requests[k], key=lambda req: a(req["drop_off"], current_vehicle_location[k]))
                current_vehicle_location[k] = nearest_drop_off_location["drop_off"] # driving to the drop off location
                routes[k].append(nearest_drop_off_location["index"] + instance.n) # writing down the location index in our route
                current_vehicle_requests[k].remove(nearest_drop_off_location) # not our request anymore
                current_vehicle_capacity[k] -= nearest_drop_off_location["demand"] # freeing some loading capacity
                n_served += 1 # we have succesfully completed one request!
    return routes

# %%
filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
instance = Instance(filename)
routes = nearest_neighbor_heuristic(instance)

# %%
plot_routes(instance, routes)

# %% [markdown]
# ## Subtask 2: Deriving a randomized construction heuristic
# to be applied iteratively, yielding diverse promising results. For that we are going to take our Nearest Neighbor Heuristic, but modify it so that the vehicles decide randomly to pick up (if they can) or drop of (if they can). We should probably include a parameter that controls the bias towards one or the other. This is the "bias" parameter:
# * if it is set to 0, the vehicle will always try to pick up more stuff if possible
# * if it is set to 1, the vehicle will always try to drop off more stuff if possible

# %%
def randomized_nearest_neighbor_heuristic(instance, bias):
    open_requests = instance.requests.copy()
    routes = [[] for _ in range(instance.n_k)]
    current_vehicle_location = [instance.depot for _ in range(instance.n_k)]
    current_vehicle_capacity = [0 for _ in range(instance.n_k)]
    current_vehicle_requests = [[] for _ in range(instance.n_k)]
    n_served = 0
    while n_served < instance.gamma:
        for k in range(instance.n_k):
            random_number = random.random()
            if not open_requests and not current_vehicle_requests[k]:
                continue
            #print(f"lenopenreq: {len(open_requests)}")

            nearest_pick_up_location = None
            if open_requests:
                nearest_pick_up_location = min(
                    open_requests,
                    key=lambda req: a(req["pick_up"], current_vehicle_location[k])
                )
            if (nearest_pick_up_location is not None and
                (bias <= random_number or len(current_vehicle_requests[k]) == 0) and
                nearest_pick_up_location["demand"] + current_vehicle_capacity[k] <= instance.C):
                #print(f"PICKING UP: {nearest_pick_up_location}")
                #print(nearest_pick_up_location["demand"] + current_vehicle_capacity[k])
                current_vehicle_location[k] = nearest_pick_up_location["pick_up"] # we are driving to the new pick up location
                routes[k].append(nearest_pick_up_location["index"]) # write it down in our route list
                current_vehicle_requests[k].append(nearest_pick_up_location) # take the request
                current_vehicle_capacity[k] += nearest_pick_up_location["demand"] # use some loading capacity
                open_requests.remove(nearest_pick_up_location) # it's not an open request anymore
            elif current_vehicle_requests[k]:
                nearest_drop_off_location = min(current_vehicle_requests[k], key=lambda req: a(req["drop_off"], current_vehicle_location[k]))
                #print(f"DROPPING OFF: {nearest_drop_off_location}")
                current_vehicle_location[k] = nearest_drop_off_location["drop_off"] # driving to the drop off location
                routes[k].append(nearest_drop_off_location["index"] + instance.n) # writing down the location index in our route
                current_vehicle_requests[k].remove(nearest_drop_off_location) # not our request anymore
                current_vehicle_capacity[k] -= nearest_drop_off_location["demand"] # freeing some loading capacity
                n_served += 1 # we have succesfully completed one request!
    while any(current_vehicle_requests):
        for k in range(instance.n_k):
            if current_vehicle_requests[k]:

                nearest_drop_off_location = min(
                    current_vehicle_requests[k],
                    key=lambda req: a(req["drop_off"], current_vehicle_location[k])
                )

                current_vehicle_location[k] = nearest_drop_off_location["drop_off"]
                routes[k].append(nearest_drop_off_location["index"] + instance.n)
                current_vehicle_requests[k].remove(nearest_drop_off_location)
                current_vehicle_capacity[k] -= nearest_drop_off_location["demand"]
                n_served += 1
    return routes

# %%
filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
instance = Instance(filename)
routes = randomized_nearest_neighbor_heuristic(instance, 0.5)

# %%
objective_function(instance, routes)
# Out:
# 5418.092656680647

# %%
plot_routes(instance, routes)

# %% [markdown]
# ### Another randomized Seconstruction heuristic
# As we will find out later, this one is not so well suited for GRASP. This is why we generated another randomized constructio heuristic, based on our neearest neighbor constr. Heur.
# This one samples from the k nearest candidates instead of always choosing the nearest one.

# %%
def another_randomized_nearest_neighbor_heuristic(instance, k=5):
    open_requests = instance.requests.copy()
    routes = [[] for _ in range(instance.n_k)]
    current_vehicle_location = [instance.depot for _ in range(instance.n_k)]
    current_vehicle_capacity = [0 for _ in range(instance.n_k)]
    current_vehicle_requests = [[] for _ in range(instance.n_k)]

    n_served = 0

    def k_nearest(elements, location, attr, k):
        """Return a random element chosen from the k nearest ones."""
        if not elements:
            return None
        sorted_elems = sorted(elements, key=lambda req: a(req[attr], location))
        k = min(k, len(sorted_elems))
        return random.choice(sorted_elems[:k])

    while n_served < instance.gamma:

        for k_i in range(instance.n_k):

            if not open_requests and not current_vehicle_requests[k_i]:
                continue

            # ---- PICKUP CANDIDATES ------------------------------------------------
            pickup_candidate = None
            if open_requests:
                pickup_candidate = k_nearest(open_requests, current_vehicle_location[k_i], "pick_up", k)

            # ---- PICKUP STEP ------------------------------------------------------
            if (pickup_candidate is not None and
                pickup_candidate["demand"] + current_vehicle_capacity[k_i] <= instance.C):

                current_vehicle_location[k_i] = pickup_candidate["pick_up"]
                routes[k_i].append(pickup_candidate["index"])
                current_vehicle_requests[k_i].append(pickup_candidate)
                current_vehicle_capacity[k_i] += pickup_candidate["demand"]
                open_requests.remove(pickup_candidate)

            # ---- DROP-OFF STEP ----------------------------------------------------
            elif current_vehicle_requests[k_i]:
                drop_candidate = k_nearest(current_vehicle_requests[k_i], current_vehicle_location[k_i], "drop_off", k)

                current_vehicle_location[k_i] = drop_candidate["drop_off"]
                routes[k_i].append(drop_candidate["index"] + instance.n)
                current_vehicle_requests[k_i].remove(drop_candidate)
                current_vehicle_capacity[k_i] -= drop_candidate["demand"]
                n_served += 1

    # ---- FINAL DROP-OFF LOOP ----------------------------------------------------
    while any(current_vehicle_requests):
        for k_i in range(instance.n_k):
            if current_vehicle_requests[k_i]:
                drop_candidate = k_nearest(current_vehicle_requests[k_i], current_vehicle_location[k_i], "drop_off", k)
                current_vehicle_location[k_i] = drop_candidate["drop_off"]
                routes[k_i].append(drop_candidate["index"] + instance.n)
                current_vehicle_requests[k_i].remove(drop_candidate)
                current_vehicle_capacity[k_i] -= drop_candidate["demand"]
                n_served += 1

    return routes

# %% [markdown]
# ## Subtask 3: Pilot / Beam Search
#
# In this subtask, we are asked to develop either a Beam Search or a Pilot Search algorithm to hopefully improve our performance.
# At first glance, Pilot Search appears attractive because it provides a more accurate evaluation of each decision by performing a complete greedy rollout for every candidate move:
#
# | Aspect | **Beam Search** | **Pilot Search** |
# |--------|------------------|------------------|
# | **Core Idea** | Keep the β most promising partial solutions at each level | Evaluate each extension by completing it with a greedy rollout |
# | **Evaluation Method** | Objective function on partial solutions | Full greedy completion from each extension |
# | **Nodes Explored** | O(β·n) | O(n²) |
# | **Computational Cost** | Lower (only evaluates partial solutions) | Higher (requires full greedy completion per extension) |
# | **Look-Ahead** | Limited to the current level | Dynamic via simulated completions |
# | **Accuracy** | Depends on objective quality | Generally higher (accounts for downstream effects) |
#
# However, we encountered a structural issue in our previous algorithm design:
# our heuristics optimized the vehicle routes in a round-robin fashion, meaning all vehicles were advanced simultaneously.
# As a result, if the optimal behavior was something like
# > “Vehicle 1 picks up request 5 and then immediately request 7 because it’s nearby,”
# this was not possible — the algorithm would switch to vehicle 2 right after assigning a single request to vehicle 1.
#
# To enable independent optimization of each vehicle’s route, we propose defining the node set as:
#
# $$
# (\text{set of all vehicles}) \times ((\text{open and feasible pickups}) \cup (\text{current requests for drop-off}))
# $$
#
# However, the nearest-neighbor heuristic we used earlier is not suitable for such independent vehicle optimization.
# It also ignores the fairness objective, making it unreliable as a rollout policy for a Pilot Search.
#
# **Therefore, we decided to implement a Beam Search approach**,
# which evaluates partial global solutions directly and naturally supports both multi-vehicle coordination and the fairness objective.
# In order to build the search tree, we also define a "Node" class, that represents a node in this search tree.

# %%
# creating an own class to represent the nodes
@dataclass
class Node:
    routes: list           # list[list[int]]
    loc: list              # current location per vehicle
    capacity: list              # current used capacity
    onboard: list          # onboard[k] = list of requests
    open_reqs: list        # list of remaining requests
    n_served: int
    score: float           # evaluation score

    def copy(self):
        """Create a deep copy of the state, but without copying the underlying request dicts."""
        return Node(
            routes=[r.copy() for r in self.routes],
            loc=self.loc.copy(),
            capacity=self.capacity.copy(),
            onboard=[lst.copy() for lst in self.onboard],
            open_reqs=self.open_reqs.copy(),
            n_served=self.n_served,
            score=self.score
        )

# %%
# create the children nodes
def expand_node(instance, node):
    if node.open_reqs == [] and all(len(o)==0 for o in node.onboard):
        print("No possible moves in this state, served: ", node.n_served)
    successors = []
    for k in range(instance.n_k):
        # Pick up successors
        for req in node.open_reqs:
            if node.capacity[k] + req["demand"] <= instance.C:
                S2 = node.copy()
                old_loc = S2. loc[k] # move old vehicle
                new_loc = req["pick_up"]
                S2.loc[k] = new_loc
                S2.routes[k].append(req["index"])
                S2.onboard[k].append(req)
                S2.open_reqs.remove(req)
                S2.capacity[k] += req["demand"]
                S2.score  = objective_function(instance, S2.routes)
                successors.append(S2)
        # Drop off successors
        for req in node.onboard[k]:
            S2 = node.copy()
            old_loc = S2.loc[k]
            new_loc = req["drop_off"]
            S2.loc[k] = new_loc
            S2.routes[k].append(req["index"] + instance.n)
            S2.onboard[k].remove(req)
            S2.capacity[k] -= req["demand"]
            S2.score = objective_function(instance, S2.routes)
            S2.n_served += 1
            successors.append(S2)
    return successors

def flush_dropoffs(instance, node):
    for k in range(instance.n_k):
        while node.onboard[k]: # as long as we have still requests in the vehicle
            req = node.onboard[k][0] # take the first request on board of the vehicle
            node.loc[k] = req["drop_off"] # set the vehicle location to the drop of point
            node.routes[k].append(req["index"] + instance.n) # appending drop off location to route
            node.capacity[k] -= req["demand"] # decreasing capacity
            node.onboard[k].remove(req)
            node.n_served += 1
    return node

# %%
def beam_search(instance, beta):
    init = Node(
        routes = [[] for _ in range(instance.n_k)],
        loc = [instance.depot for _ in range(instance.n_k)],
        capacity = [0 for _ in range(instance.n_k)],
        onboard=[[] for _ in range(instance.n_k)],
        open_reqs=instance.requests.copy(),
        n_served=0,
        score=0.0
    )
    beam = [init]
    while True:
        if all(s.n_served >= instance.gamma for s in beam):
            out = min(successors, key=lambda s: s.score)
            for k in range(instance.n_k): # delivering the remaining drop offs
                while out.onboard[k]: # as long as we have still requests in the vehicle
                    req = out.onboard[k][0] # take the first request on board of the vehicle
                    out.loc[k] = req["drop_off"] # set the vehicle location to the drop of point
                    out.routes[k].append(req["index"] + instance.n) # appending drop off location to route
                    out.capacity[k] -= req["demand"] # decreasing capacity
                    out.onboard[k].remove(req)
                    out.n_served += 1
            return out.routes
        successors = []
        for s in beam:
            successors.extend(expand_node(instance, s))

        successors.sort(key=lambda s: s.score)
        beam = successors[:beta]

# %%
instance = Instance("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
routes = beam_search(instance, 50)
plot_routes(instance, routes)

# %% [markdown]
# ## Subtask 4: Developing a framework for basic local search
#
# which is able to deal with **different neighborhood structures** and different **step functions**
#
# Because we experimented quite a bit, we  implemented more than three neighborhood structures:
#
# 1. **RelocateCompact**: Takes a request from Vehicle A and moves it to Vehicle B, where Vehicle B drops off the request immediately after pickup.
#
# 2. **RelocateFlexible**: Takes a request from Vehicle A and moves it to Vehicle B, attempting to drop it off not immediately but at a later, feasible time. So it basically does the same  as relocateCompact, but gives us more neighbors (and is more expansive to evaluate)
#
# 3. **RelocateRandomly**: A special randomized version of flexible relocation, designed specifically for Simulated Annealing. Instead of generating all possible neighbors, it randomly selects one vehicle with pickups, one request from that vehicle, and one target vehicle, then randomly chooses a feasible insertion. Not really suited for LS/VND/GRASP in general, but made specifically for SA.
#
# 4. **SwapRequests**: Swaps a request from Vehicle A with a request from Vehicle B, attempting all feasible compact insertion positions for both requests in their new vehicles. Very expensive, only first_improvement is recomended with this neighborhood since best_improvement takes for ever for a single iteration. And since best_improvement generally produces better results, this neighborhood structure is not used that much.
#
# 5. **DelayDropoffs**: For each drop-off in each vehicle's route, tries to move the drop-off as far back (later) in the route as possible while maintaining capacity feasibility and ensuring the pickup remains before the drop-off. The goal of this neighborhood structure is ptimicing the capacity of each vehicle.
#
# 6. **AdvancePickups**: For each pickup in each vehicle's route, tries to move the pickup as early (forward) in the route as possible while maintaining capacity feasibility and ensuring the pickup remains before the drop-off. Again, the goal of this neighborhood structure is ptimicing the capacity of each vehicle.
#
# 7. **ReplaceWithUnserved**: Replaces a currently served request with an unserved request, exploring all feasible compact insertion positions for the new request. Only useful when gamma < n.
#
# Down below, you can also find delta-evaluated versions of some of the neighborhood structures.
# Furthermore, we have created a new State class that only consists of the data we need for efficient local search operations.

# %%
@dataclass(frozen=True)
class State:
    routes: tuple[tuple[int]]
    served: frozenset
    unserved: frozenset
    score: float

    @staticmethod
    def from_routes(instance, routes):
        """Build State from raw routes (list of lists)."""
        served = set()
        for vroute in routes:
            for idx in vroute:
                if idx < instance.n:
                    served.add(idx)
        served = frozenset(served)
        unserved = frozenset(set(range(instance.n)) - served)
        score = objective_function(instance, routes)
        return State(
            routes=tuple(tuple(r) for r in routes),
            served=served,
            unserved=unserved,
            score=score
        )

# %%
# Some utility functions
def remove_request_from_route(route, req_idx, n):
    """Remove both pickup(req_idx) and dropoff(req_idx+n)."""
    new_route = [x for x in route if x != req_idx and x != req_idx+n]
    return new_route


def insert_request_compact(route, req_idx, n):
    """Insert pickup and then dropoff immediately after."""
    new_route = route.copy()
    # insert pickup at all possible positions
    for pos in range(len(route)+1):
        tmp = new_route[:pos] + [req_idx, req_idx + n] + new_route[pos:]
        yield tmp

# limited window version of insert_request_compact
def insert_request_compact_window(route, req_idx, n, window=2):
    L = len(route)
    # find original position if exists
    original_pos = None
    for i, x in enumerate(route):
        if x == req_idx:
            original_pos = i
            break
        # define positions to try
        if original_pos is not None:
            start = max(0, original_pos - window)
            end = min(L+1, original_pos + window + 1)
            positions = range(start, end)
        else:
            positions = range(L+1)
        for pos in positions:
            tmp = route[:pos] + [req_idx, req_idx+n] + route[pos:]
            yield tmp

def insert_request_flexible(route, req_idx, n):
    """Try all pickup and dropoff insertion positions (pickup_pos < dropoff_pos)."""
    L = len(route)
    for p in range(L+1):            # pickup position
        for d in range(p+1, L+2):   # dropoff position after pickup
            new_r = route[:p] + [req_idx] + route[p:d] + [req_idx+n] + route[d:]
            yield new_r


def capacity_feasible(instance, route):
    """Check capacity along route."""
    load = 0
    for idx in route:
        #idx = idx - 1
        if idx <= instance.n:    # pickup
            load += instance.requests[idx - 1]["demand"] # fucking off-by-one
            #print(f"Picking up load for idx {idx}, capacity is now at {load}")
            if load > instance.C:
                #print("Load too high!!")
                return False
        else:                   # dropoff
            #print(f"(real) index {real} (idx: {idx}) has demand {instance.requests[real]["demand"]} while current load is {load}")
            load -= instance.requests[idx - instance.n - 1]["demand"]
            if load < 0:
                #print("Load below zero!!")
                return False
    return True

# %%
class RelocateCompact:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]
        for v_from, route_from in enumerate(routes):
            for idx in route_from:
                if idx >= self.n:
                    continue     # dropoff, skip
                req_idx = idx
                # Try removing from one vehicle, inserting in another
                for v_to in range(len(routes)):
                    if v_to == v_from:
                        continue
                    r_from = remove_request_from_route(route_from, req_idx, self.n)
                    for r_to in insert_request_compact(routes[v_to], req_idx, self.n):
                        if capacity_feasible(self.instance, r_to) and capacity_feasible(self.instance, r_from):
                            new_routes = []
                            for k, r in enumerate(routes):
                                if k == v_from:
                                    new_routes.append(r_from)
                                elif k == v_to:
                                    new_routes.append(r_to)
                                else:
                                    new_routes.append(r)
                            yield State.from_routes(self.instance, new_routes)


# takin request from one vehicle to another vehicle
class RelocateFlexible:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes] # converting to list
        for v_from, route_from in enumerate(routes): # vehicle and route
            for idx in route_from:
                if idx >= self.n: # it's a drop-off index
                    continue
                req_idx = idx # it's a pick up index
                for v_to in range(len(routes)): # iterating over all other possible vehicles
                    if v_to == v_from: # we obviously don't want to move to our own vehicle again
                        continue
                    r_from = remove_request_from_route(route_from, req_idx, self.n)
                    for r_to in insert_request_flexible(routes[v_to], req_idx, self.n): # iterating over all
                        if capacity_feasible(self.instance, r_to) and capacity_feasible(self.instance, r_from): # feasible drop-off locations
                            new_routes = []
                            for k, r in enumerate(routes):
                                if k == v_from:
                                    new_routes.append(r_from)
                                elif k == v_to:
                                    new_routes.append(r_to)
                                else:
                                    new_routes.append(r)
                            yield State.from_routes(self.instance, new_routes)

# special version, later used for Simulated Annealing
class RelocateRandomly:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state:State):
        routes = [list(r) for r in state.routes] # converting to list
        vehicles_with_pickups = [i for i, r in enumerate(routes) if any(idx < self.n for idx in r)] # pick a random vehicle with at least one pickup
        if not vehicles_with_pickups:
            print("No vehicle with pickups!")
            return  # no feasible move

        v_from = random.choice(vehicles_with_pickups)
        route_from = routes[v_from]

        # pick a random pickup in that vehicle
        pickup_indices = [idx for idx in route_from if idx < self.n]
        req_idx = random.choice(pickup_indices)

        # pick a random other vehicle to move to
        v_to_candidates = [i for i in range(len(routes)) if i != v_from]
        v_to = random.choice(v_to_candidates)
        route_to = routes[v_to]

        # remove request from original route
        r_from = remove_request_from_route(route_from, req_idx, self.n)

        # try inserting randomly into the target vehicle
        # try inserting randomly into the target vehicle, only keep feasible insertions
        feasible_insertions = [
            r for r in insert_request_flexible(route_to, req_idx, self.n)
            if capacity_feasible(self.instance, r)
        ]
        if not feasible_insertions:
            print("No feasable insertion!")
            return  # no feasible insertion
        r_to = random.choice(feasible_insertions)

        # assemble new routes
        new_routes = []
        for k, r in enumerate(routes):
            if k == v_from:
                new_routes.append(r_from)
            elif k == v_to:
                new_routes.append(r_to)
            else:
                new_routes.append(r)

        # yield a single random neighbor
        yield State.from_routes(self.instance, new_routes)

# the problem with this class is that it is impossible to use with best improvement because it literally creates millions of neighbors.
class SwapRequests:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]
        # all pairs of vehicles
        for v1 in range(len(routes)):
            for v2 in range(v1+1, len(routes)):
                for idx1 in routes[v1]:
                    if idx1 >= self.n:
                        continue
                    for idx2 in routes[v2]:
                        if idx2 >= self.n:
                            continue

                        # remove both requests
                        r1_rem = remove_request_from_route(routes[v1], idx1, self.n)
                        r2_rem = remove_request_from_route(routes[v2], idx2, self.n)

                        # try inserting each into the other vehicle (compact insertion)
                        for r1_add in insert_request_compact(r1_rem, idx2, self.n):
                            for r2_add in insert_request_compact(r2_rem, idx1, self.n):
                                if capacity_feasible(self.instance, r1_add) and capacity_feasible(self.instance, r2_add):
                                    new_routes = []
                                    for k, r in enumerate(routes):
                                        if k == v1:
                                            new_routes.append(r1_add)
                                        elif k == v2:
                                            new_routes.append(r2_add)
                                        else:
                                            new_routes.append(r)
                                    yield State.from_routes(self.instance, new_routes)



class DelayDropoffs:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n  # number of requests

    @staticmethod
    def _remove_at(route, pos):
        """Return a new list with element at pos removed."""
        return route[:pos] + route[pos+1:]

    @staticmethod
    def _insert_at(route, pos, node):
        """Return a new list with node inserted at pos."""
        return route[:pos] + [node] + route[pos:]

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]  # copy outer list, keep inner lists as copies
        num_vehicles = len(routes)

        for v in range(num_vehicles):
            route = routes[v]
            L = len(route)
            # iterate over positions and find drop-offs
            for pos in range(L):
                node = route[pos]
                if node <= self.n:
                    # pickup node, skip
                    continue

                # node is a drop-off (value in n+1 .. 2n)
                drop_req = node - self.n  # request id (1-based)
                # find pickup position in this route (must exist if route is legal)
                try:
                    pickup_pos = route.index(drop_req)
                except ValueError:
                    # pickup not in same route: skip (we only reorder within same vehicle)
                    continue

                # candidate positions are from pos+1 up to len(route) (inclusive at end)
                # we want the farthest position j such that inserting the drop at j keeps feasibility
                # (we remove original drop at pos first, then try to insert at later positions)
                route_without_drop = self._remove_at(route, pos)
                best_pos = None

                # Try insertion positions from the end backwards to find maximal feasible push quickly
                for j in range(len(route_without_drop), pos, -1):
                    candidate = self._insert_at(route_without_drop, j, node)
                    # Ensure pickup still before drop (pickup_pos may shift if pickup was after removed pos)
                    # Compute new pickup position:
                    # if pickup_pos < pos: pickup_pos unchanged
                    # if pickup_pos > pos: pickup_pos' = pickup_pos - 1
                    if pickup_pos > pos:
                        new_pickup_pos = pickup_pos - 1
                    else:
                        new_pickup_pos = pickup_pos
                    # new drop pos is j (since inserted at j in route_without_drop)
                    new_drop_pos = j
                    if new_pickup_pos >= new_drop_pos:
                        # pickup would be after or at same position as drop -> invalid
                        continue

                    # capacity feasibility check for this candidate route (whole-route check, but it's cheap)
                    if capacity_feasible(self.instance, candidate):
                        best_pos = j
                        # since we're iterating from far to near, the first feasible j is the maximal push
                        break

                if best_pos is not None and best_pos != pos:
                    # build new_routes with this pushed drop-off for vehicle v
                    new_routes = []
                    for k, r in enumerate(routes):
                        if k == v:
                            new_routes.append(self._insert_at(self._remove_at(r, pos), best_pos, node))
                        else:
                            new_routes.append(r)
                    yield State.from_routes(self.instance, new_routes)


class AdvancePickups:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    @staticmethod
    def _remove_at(route, pos):
        return route[:pos] + route[pos+1:]

    @staticmethod
    def _insert_at(route, pos, node):
        return route[:pos] + [node] + route[pos:]

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]
        num_vehicles = len(routes)

        for v in range(num_vehicles):
            route = routes[v]
            L = len(route)

            for pos in range(L):
                node = route[pos]
                if node > self.n:
                    # skip drop-offs
                    continue

                pickup = node
                drop = pickup + self.n

                # locate drop position
                try:
                    drop_pos = route.index(drop)
                except ValueError:
                    # drop is not in same route, skip
                    continue

                # Remove pickup
                route_wo_pickup = self._remove_at(route, pos)

                # drop position shifts left by 1 only if pickup was before drop
                if pos < drop_pos:
                    new_drop_pos = drop_pos - 1
                else:
                    new_drop_pos = drop_pos

                best_pos = None

                # Try earliest positions: from 0 up to new_drop_pos-1
                # We iterate forward so the *first* feasible is the earliest possible
                for j in range(0, new_drop_pos):
                    candidate = self._insert_at(route_wo_pickup, j, pickup)

                    # new pickup position = j
                    # drop node is still at new_drop_pos
                    # but if j <= new_drop_pos: drop shifts right by +1
                    if j <= new_drop_pos:
                        candidate_drop_pos = new_drop_pos + 1
                    else:
                        candidate_drop_pos = new_drop_pos

                    # enforce pickup < drop
                    if j >= candidate_drop_pos:
                        continue

                    # capacity check
                    if capacity_feasible(self.instance, candidate):
                        best_pos = j
                        break

                # if we found an earlier feasible position
                if best_pos is not None and best_pos != pos:
                    new_routes = []
                    for k, r in enumerate(routes):
                        if k == v:
                            new_routes.append(self._insert_at(self._remove_at(r, pos), best_pos, pickup))
                        else:
                            new_routes.append(r)

                    yield State.from_routes(self.instance, new_routes)


class ReplaceWithUnserved:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]

        # find all currently served requests
        served = set()
        for r in routes:
            for x in r:
                if x < self.n:
                    served.add(x)

        # unserved candidates
        unserved = [i for i in range(self.n) if i not in served]

        if not unserved:
            return  # no moves possible

        for v, route in enumerate(routes):
            # iterate over served requests in this vehicle
            for req_out in route:
                if req_out >= self.n:
                    continue  # dropoff, skip

                # remove this request from the route
                route_removed = remove_request_from_route(route, req_out, self.n)

                # try replacing it with an unserved one
                for req_in in unserved:
                    # insert at all possible compact positions
                    for route_added in insert_request_compact(route_removed, req_in, self.n):

                        # check feasibility
                        if not capacity_feasible(self.instance, route_added):
                            continue

                        # build full solution
                        new_routes = []
                        for k, r in enumerate(routes):
                            if k == v:
                                new_routes.append(route_added)
                            else:
                                new_routes.append(r)

                        yield State.from_routes(self.instance, new_routes)

# %% [markdown]
# Here are the delta evaluated versions. However, they are generally not faster than the normal ones

# %%
# Here's the same code but with delta evaluation:
class RelocateCompact_delta:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]
        for v_from, route_from in enumerate(routes):
            for idx in route_from:
                if idx >= self.n:
                    continue     # dropoff, skip
                req_idx = idx
                # Try removing from one vehicle, inserting in another
                for v_to in range(len(routes)):
                    if v_to == v_from:
                        continue
                    r_from = remove_request_from_route(route_from, req_idx, self.n)
                    for r_to in insert_request_compact(routes[v_to], req_idx, self.n):
                        if capacity_feasible(self.instance, r_to) and capacity_feasible(self.instance, r_from):
                            new_routes = []
                            for k, r in enumerate(routes):
                                if k == v_from:
                                    new_routes.append(r_from)
                                elif k == v_to:
                                    new_routes.append(r_to)
                                else:
                                    new_routes.append(r)

                            delta = delta_objective(
                                self.instance,
                                state.routes,                    # old state routes (tuple of tuples)
                                tuple(tuple(r) for r in new_routes)  # new routes in same format
                            )
                            new_score = state.score + delta
                            yield State(
                                routes=tuple(tuple(r) for r in new_routes),
                                served=state.served,      # you can recompute if needed
                                unserved=state.unserved,
                                score=new_score
                            )

class RelocateFlexible_delta:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes] # converting to list
        for v_from, route_from in enumerate(routes): # vehicle and route
            for idx in route_from:
                if idx >= self.n: # it's a drop-off index
                    continue
                req_idx = idx # it's a pick up index
                for v_to in range(len(routes)): # iterating over all other possible vehicles
                    if v_to == v_from: # we obviously don't want to move to our own vehicle again
                        continue
                    r_from = remove_request_from_route(route_from, req_idx, self.n)
                    for r_to in insert_request_flexible(routes[v_to], req_idx, self.n): # iterating over all
                        if capacity_feasible(self.instance, r_to) and capacity_feasible(self.instance, r_from): # feasible drop-off locations
                            new_routes = []
                            for k, r in enumerate(routes):
                                if k == v_from:
                                    new_routes.append(r_from)
                                elif k == v_to:
                                    new_routes.append(r_to)
                                else:
                                    new_routes.append(r)
                            delta =  delta = delta_objective(
                                self.instance,
                                state.routes,                    # old state routes (tuple of tuples)
                                tuple(tuple(r) for r in new_routes)  # new routes in same format
                            )
                            new_score = state.score + delta
                            yield State(
                                routes=tuple(tuple(r) for r in new_routes),
                                served=state.served,      # you can recompute if needed
                                unserved=state.unserved,
                                score=new_score
                            )

# special version, later used for Simulated Annealing
class RelocateRandomly_delta:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state:State):
        routes = [list(r) for r in state.routes] # converting to list
        vehicles_with_pickups = [i for i, r in enumerate(routes) if any(idx < self.n for idx in r)] # pick a random vehicle with at least one pickup
        if not vehicles_with_pickups:
            return  # no feasible move

        v_from = random.choice(vehicles_with_pickups)
        route_from = routes[v_from]

        # pick a random pickup in that vehicle
        pickup_indices = [idx for idx in route_from if idx < self.n]
        req_idx = random.choice(pickup_indices)

        # pick a random other vehicle to move to
        v_to_candidates = [i for i in range(len(routes)) if i != v_from]
        v_to = random.choice(v_to_candidates)
        route_to = routes[v_to]

        # remove request from original route
        r_from = remove_request_from_route(route_from, req_idx, self.n)

        # try inserting randomly into the target vehicle
        # try inserting randomly into the target vehicle, only keep feasible insertions
        feasible_insertions = [
            r for r in insert_request_flexible(route_to, req_idx, self.n)
            if capacity_feasible(self.instance, r)
        ]
        if not feasible_insertions:
            return  # no feasible insertion
        r_to = random.choice(feasible_insertions)

        # assemble new routes
        new_routes = []
        for k, r in enumerate(routes):
            if k == v_from:
                new_routes.append(r_from)
            elif k == v_to:
                new_routes.append(r_to)
            else:
                new_routes.append(r)

        # yield a single random neighbor
        delta =  delta = delta_objective(
                                self.instance,
                                state.routes,                    # old state routes (tuple of tuples)
                                tuple(tuple(r) for r in new_routes)  # new routes in same format
                            )
        new_score = state.score + delta
        yield State(
            routes=tuple(tuple(r) for r in new_routes),
            served=state.served,      # you can recompute if needed
            unserved=state.unserved,
            score=new_score
        )

class SwapRequests_delta:
    def __init__(self, instance):
        self.instance = instance
        self.n = instance.n

    def neighbors(self, state: State):
        routes = [list(r) for r in state.routes]

        # all pairs of vehicles
        for v1 in range(len(routes)):
            for v2 in range(v1+1, len(routes)):
                for idx1 in routes[v1]:
                    if idx1 >= self.n:
                        continue
                    for idx2 in routes[v2]:
                        if idx2 >= self.n:
                            continue

                        # remove both requests
                        r1_rem = remove_request_from_route(routes[v1], idx1, self.n)
                        r2_rem = remove_request_from_route(routes[v2], idx2, self.n)

                        # try inserting each into the other vehicle (compact insertion)
                        for r1_add in insert_request_compact(r1_rem, idx2, self.n):
                            for r2_add in insert_request_compact(r2_rem, idx1, self.n):
                                if capacity_feasible(self.instance, r1_add) and capacity_feasible(self.instance, r2_add):
                                    new_routes = []
                                    for k, r in enumerate(routes):
                                        if k == v1:
                                            new_routes.append(r1_add)
                                        elif k == v2:
                                            new_routes.append(r2_add)
                                        else:
                                            new_routes.append(r)
                                        delta = delta_objective(
                                            self.instance,
                                            state.routes,                    # old state routes (tuple of tuples)
                                            tuple(tuple(r) for r in new_routes)  # new routes in same format
                                        )
                                        new_score = state.score + delta
                                        yield State(
                                            routes=tuple(tuple(r) for r in new_routes),
                                            served=state.served,      # you can recompute if needed
                                            unserved=state.unserved,
                                            score=new_score
                                        )

# %% [markdown]
# We define the **first improevement** and **best imporvement** step functions

# %%
def first_improvement(state, neighborhood):
    i = 0
    for neigh in neighborhood.neighbors(state):
        i += 1
        if neigh.score < state.score:
            #print(f"found fist improvement after looking at {i} neighbors")
            return neigh
    #print(f"Did not find an improvement after lookign at {i} neighbors")
    return state

def best_improvement(state, neighborhood):
    best = state
    i = 0
    for neigh in neighborhood.neighbors(state):
        i += 1
        if neigh.score < best.score:
            best = neigh
    #print("Found new best neighbor in neighborhood of size: ", i)
    return best

# %% [markdown]
# ## Subtask 5: Develop at least three different meaningful neighborhood structures (and LOCAL SEARCH!)
# We have already done this in the previous part. But now let's test these neighborhood srtructures by implementing a simple local search algorithm.

# %%
def local_search(instance, routes, neighborhood, step_function, max_iter):
    state = State.from_routes(instance, routes)
    i = 0
    for it in range(max_iter):
        i += 1
        improved = False
        new_state = step_function(state, neighborhood)
        if new_state.score < state.score:
            state = new_state
            improved = True
            #if improved:
                #print("Improved Score to: ", state.score)
        if not improved:
            break
    print(f"ran {i} iterations")
    return state.routes

# %%
filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
instance = Instance(filename)
routes = beam_search(instance, 50)
print("score for initial routes: ", objective_function(instance, routes))
routes_improved = local_search(instance, routes, RelocateFlexible(instance), best_improvement, 100)
print("score of improved routes: ", objective_function(instance, routes_improved))
# Out:
# score for initial routes:  3821.7317828479413
# ran 7 iterations
# score of improved routes:  3733.101279260549

# %% [markdown]
# ### Quick Experiment:
# Since it says in our assignment:
# >
# > Use the solution of the deterministic construction heuristic to test the other implementations:
# > i. Local search for at least three selected (possibly composite) neighborhood structures using
# > each of the two step functions (i.e., at least six different algorithm variants)
# >
# we are going to do that now

# %%
def run_local_search_wrapper(instance, routes, neighborhoods, step_functions, max_iter=50):
    """
    Run local search on initial routes with multiple neighborhoods and step functions.
    Returns a dictionary with results for plotting.
    """
    results = {}

    for neigh in neighborhoods:
        neigh_name = neigh.__class__.__name__
        for step_func in step_functions:
            func_name = step_func.__name__
            # Reset initial routes each time
            print(f"Running {neigh_name} with {func_name}")
            start = time.time()
            improved_routes = local_search(instance, routes, neigh, step_func, max_iter)
            end = time.time()
            runtime = end - start
            score = objective_function(instance, improved_routes)
            results[f"{neigh_name} - {func_name}"] = {
                "routes": improved_routes,
                "score": score,
                "runtime": runtime
            }
            print(f"Score for {neigh_name} - {func_name}: {score}, runtime: {runtime:.3f} sec")
    return results

# %%
neighborhoods = [RelocateCompact(instance), RelocateFlexible(instance), DelayDropoffs(instance), AdvancePickups(instance)]
step_functions = [first_improvement, best_improvement]

filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
instance = Instance(filename)
routes = nearest_neighbor_heuristic(instance)
print("Score for initial routes: ", objective_function(instance, routes))

results = run_local_search_wrapper(instance, routes, neighborhoods, step_functions, max_iter=100)
# Out:
# Score for initial routes:  5045.017549591446
# Running RelocateCompact with first_improvement
# ran 57 iterations
# Score for RelocateCompact - first_improvement: 4498.121001454709, runtime: 20.702 sec
# Running RelocateCompact with best_improvement
# ran 30 iterations
# Score for RelocateCompact - best_improvement: 4444.000025568693, runtime: 19.112 sec
# Running RelocateFlexible with first_improvement
# ran 100 iterations
# Score for RelocateFlexible - first_improvement: 4266.470936695634, runtime: 112.607 sec
# Running RelocateFlexible with best_improvement
# ran 30 iterations
# Score for RelocateFlexible - best_improvement: 4310.123369832163, runtime: 67.232 sec
# Running DelayDropoffs with first_improvement
# ran 4 iterations
# Score for DelayDropoffs - first_improvement: 5037.015875648013, runtime: 0.049 sec
# Running DelayDropoffs with best_improvement
# ran 4 iterations
# Score for DelayDropoffs - best_improvement: 5037.015875648013, runtime: 0.064 sec
# Running AdvancePickups with first_improvement
# ran 5 iterations
# Score for AdvancePickups - first_improvement: 5040.01788101983, runtime: 0.044 sec
# Running AdvancePickups with best_improvement
# ran 5 iterations
# Score for AdvancePickups - best_improvement: 5040.01788101983, runtime: 0.078 sec

# %%
labels = list(results.keys())
scores = [results[k]["score"] for k in labels]
times = [results[k]["runtime"] for k in labels]

fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Score plot
ax[0].barh(labels, scores)
ax[0].set_title("Objective score (Nearest neighbor Constr.)")
ax[0].invert_yaxis()

# Runtime plot
ax[1].barh(labels, times)
ax[1].set_title("Runtime in seconds (Nearest neighbor Constr.)")
ax[1].invert_yaxis()

plt.tight_layout()
plt.show()

# %%
neighborhoods = [RelocateCompact(instance), RelocateFlexible(instance), DelayDropoffs(instance), AdvancePickups(instance)]
step_functions = [first_improvement, best_improvement]

filename = "instances/100/competition/instance61_nreq100_nveh2_gamma91.txt"
instance = Instance(filename)
routes = beam_search(instance, 50)
print("Score for initial routes: ", objective_function(instance, routes))

results = run_local_search_wrapper(instance, routes, neighborhoods, step_functions, max_iter=100)
# Out:
# Score for initial routes:  3821.7317828479413
# Running RelocateCompact with first_improvement
# ran 8 iterations
# Score for RelocateCompact - first_improvement: 3783.485822736004, runtime: 0.526 sec
# Running RelocateCompact with best_improvement
# ran 9 iterations
# Score for RelocateCompact - best_improvement: 3746.788430143489, runtime: 1.307 sec
# Running RelocateFlexible with first_improvement
# ran 12 iterations
# Score for RelocateFlexible - first_improvement: 3746.7390201617286, runtime: 3.003 sec
# Running RelocateFlexible with best_improvement
# ran 7 iterations
# Score for RelocateFlexible - best_improvement: 3733.101279260549, runtime: 5.187 sec
# Running DelayDropoffs with first_improvement
# ran 1 iterations
# Score for DelayDropoffs - first_improvement: 3821.7317828479413, runtime: 0.048 sec
# Running DelayDropoffs with best_improvement
# ran 1 iterations
# Score for DelayDropoffs - best_improvement: 3821.7317828479413, runtime: 0.049 sec
# Running AdvancePickups with first_improvement
# ran 1 iterations
# Score for AdvancePickups - first_improvement: 3821.7317828479413, runtime: 0.046 sec
# Running AdvancePickups with best_improvement
# ran 1 iterations
# Score for AdvancePickups - best_improvement: 3821.7317828479413, runtime: 0.046 sec

# %%
labels = list(results.keys())
scores = [results[k]["score"] for k in labels]
times = [results[k]["runtime"] for k in labels]

fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Score plot
ax[0].barh(labels, scores)
ax[0].set_title("Objective score (Beam Search Constr.)")
ax[0].invert_yaxis()

# Runtime plot
ax[1].barh(labels, times)
ax[1].set_title("Runtime in seconds (Beam Search Constr.)")
ax[1].invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Subtask 6: Variable Neighborhood descent
# Develop or make use of a Variable Neighborhood Descent (VND) framework which uses your
# neighborhood structures. This method is a local search metaheuristic that uses a list of neighborhood structures instead of a single one.
# Method takes advantage of the following observations:
#
# 1. A local optimum with respect to one neighborhood structure
# is not necessarily a local optimum with respect to another.
#
# 2. A global optimum is a local optimum with respect to all possible neighborhood
# structures.
#
# 3. For many problems good local optima are relatively close together.
#
#
# The order of neighborhood structures changes the solution! ("smaller" Neighborhood structures should be first)

# %%
def variable_neighborhood_descent(initial_state, neighborhoods, step_fn, max_iter=100):
    state = initial_state
    i  = 0
    for it in range(max_iter):
        i += 1
        improved = False
        for N in neighborhoods:
            new_state = step_fn(state, N)
            if new_state.score < state.score:
                #print("Improved Score to: ", state.score, "with neighborhood ", N.__class__.__name__)
                state = new_state
                improved = True
        if not improved:
            print(f"No more Improvements found after {it} iterations!")
            break
    print(f"ran {i} iterations")
    return state.routes

# %%
instance = Instance("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
#routes = nearest_neighbor_heuristic(instance)
routes = beam_search(instance, 50)
initial = State.from_routes(instance, routes)

# defining a list of neighborhoods
neighborhoods = [
    DelayDropoffs(instance),
    AdvancePickups(instance),
    RelocateCompact(instance),
    RelocateFlexible(instance),
    ReplaceWithUnserved(instance),
]

routes = variable_neighborhood_descent(
    initial,
    neighborhoods,
    step_fn=best_improvement,
    max_iter=50
)

plot_routes(instance, routes)
# Out:
# No more Improvements found after 7 iterations!
# ran 8 iterations

# %% [markdown]
# ## Subtask 7: GRASP (Greedy randomized Adaptive Search Procedure)
# Now we are asked to implement GRASP using our randomized nearest neighbor construction heuristic from earlier, togehter with a step funciton
# The algorithm works in two stages:
#
# 1.) greedy randomized construction
#
# 2.) Local search typically with best improvement

# %%
def GRASP(instance):
    solutions = []
    for i in range(10):
        random_bias = 1 - (0.1 * i)
        print(f"testing with bias {random_bias}")

        greedy_randomized = randomized_nearest_neighbor_heuristic(instance, random_bias)
        initial = State.from_routes(instance, greedy_randomized)

        neighborhoods = [
            DelayDropoffs(instance),
            AdvancePickups(instance),
            RelocateCompact(instance),
            RelocateFlexible(instance),
            ReplaceWithUnserved(instance),
        ]
        improvement = variable_neighborhood_descent(initial, neighborhoods, best_improvement, max_iter=50)
        score = objective_function(instance, improvement)
        solutions.append({"routes": improvement, "score": score})
        print(f"Score: {score}")

    # select best solution from all iterations
    best_solution = min(solutions, key=lambda s: s["score"])
    return best_solution["routes"]

# %%
instance = Instance("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
routes = GRASP(instance)
plot_routes(instance, routes)
# Out:
# testing with bias 1.0
# No more Improvements found after 23 iterations!
# ran 24 iterations
# Score: 3874.2822358032927
# testing with bias 0.9
# No more Improvements found after 31 iterations!
# ran 32 iterations
# Score: 3814.727843088163
# testing with bias 0.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 instance = Instance("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
# ----> 2 routes = GRASP(instance)
#       3 plot_routes(instance, routes)
#
# Cell In[33], line 17, in GRASP(instance)
#       8 initial = State.from_routes(instance, greedy_randomized)
#      10 neighborhoods = [
#      11     DelayDropoffs(instance),
#      12     AdvancePickups(instance),
#    (...)     15     ReplaceWithUnserved(instance),
#      16 ]
# ---> 17 improvement = variable_neighborhood_descent(initial, neighborhoods, best_improvement, max_iter=50)
#      18 score = objective_function(instance, improvement)
#      19 solutions.append({"routes": improvement, "score": score})
#
# Cell In[31], line 8, in variable_neighborhood_descent(initial_state, neighborhoods, step_fn, max_iter)
#       6 improved = False
#       7 for N in neighborhoods:
# ----> 8     new_state = step_fn(state, N)
#       9     if new_state.score < state.score:
#      10         #print("Improved Score to: ", state.score, "with neighborhood ", N.__class__.__name__)
#      11         state = new_state
#
# Cell In[23], line 14, in best_improvement(state, neighborhood)
#      12 best = state
#      13 i = 0
# ---> 14 for neigh in neighborhood.neighbors(state):
#      15     i += 1
#      16     if neigh.score < best.score:
#
# Cell In[21], line 58, in RelocateFlexible.neighbors(self, state)
#      56     else:
#      57         new_routes.append(r)
# ---> 58 yield State.from_routes(self.instance, new_routes)
#
# Cell In[19], line 18, in State.from_routes(instance, routes)
#      16 served = frozenset(served)
#      17 unserved = frozenset(set(range(instance.n)) - served)
# ---> 18 score = objective_function(instance, routes)
#      19 return State(
#      20     routes=tuple(tuple(r) for r in routes),
#      21     served=served,
#      22     unserved=unserved,
#      23     score=score
#      24 )
#
# Cell In[5], line 30, in objective_function(instance, routes)
#      28 value = 0
#      29 for route in routes:
# ---> 30     value = value + get_total_distance(instance, route)
#      31 value = value + instance.rho * (1 - get_Jain_fairness(instance, routes))
#      32 return value
#
# Cell In[5], line 13, in get_total_distance(instance, route)
#      11     next_location = instance.requests_location_array[location_index]
#      12     total_distance = total_distance + a(current_location, next_location)
# ---> 13     current_location = next_location
#      14 total_distance = total_distance + a(current_location, instance.depot)
#      15 return total_distance
#
# KeyboardInterrupt:

# %% [markdown]
# ### Another GRASP
# You can see above that the GRASP somehow does it's thing, but not really. This is we we also run grasp with another randomized construction heruistic

# %%
def anotherGRASP(instance):
    solutions = []
    for i in range(25):
        # bias controls greediness vs randomness: 1 = fully greedy, 0 = fully random
        k = 25 - i
        print(f"Testing with k {k:.2f}")
        greedy_randomized = another_randomized_nearest_neighbor_heuristic(instance, k)
        initial = State.from_routes(instance, greedy_randomized)
        neighborhoods = [DelayDropoffs(instance), AdvancePickups(instance)]
        improvement = variable_neighborhood_descent(initial, neighborhoods, best_improvement, max_iter=50)
        score = objective_function(instance, improvement)
        solutions.append({"routes": improvement, "score": score})
        print(f"Score: {score}")

    # select best solution from all iterations
    best_solution = min(solutions, key=lambda s: s["score"])
    return best_solution["routes"]

# %%
routes = anotherGRASP(instance)
plot_routes(instance, routes)
# Out:
# Testing with k 25.00
# No more Improvements found after 13 iterations!
# ran 14 iterations
# Score: 8038.05056573745
# Testing with k 24.00
# No more Improvements found after 9 iterations!
# ran 10 iterations
# Score: 8102.017346862834
# Testing with k 23.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 8078.056468175942
# Testing with k 22.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 8260.001556006742
# Testing with k 21.00
# No more Improvements found after 8 iterations!
# ran 9 iterations
# Score: 7716.001662285955
# Testing with k 20.00
# No more Improvements found after 8 iterations!
# ran 9 iterations
# Score: 7972.008390225756
# Testing with k 19.00
# No more Improvements found after 10 iterations!
# ran 11 iterations
# Score: 7995.013763964842
# Testing with k 18.00
# No more Improvements found after 8 iterations!
# ran 9 iterations
# Score: 7909.0130727111655
# Testing with k 17.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 8341.065712123516
# Testing with k 16.00
# No more Improvements found after 8 iterations!
# ran 9 iterations
# Score: 7751.030988989982
# Testing with k 15.00
# No more Improvements found after 8 iterations!
# ran 9 iterations
# Score: 7520.00057146996
# Testing with k 14.00
# No more Improvements found after 6 iterations!
# ran 7 iterations
# Score: 8111.065184299211
# Testing with k 13.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 7617.007962147959
# Testing with k 12.00
# No more Improvements found after 11 iterations!
# ran 12 iterations
# Score: 7659.000736522754
# Testing with k 11.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 7655.0239597168975
# Testing with k 10.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 7723.088266359215
# Testing with k 9.00
# No more Improvements found after 5 iterations!
# ran 6 iterations
# Score: 6883.114314604843
# Testing with k 8.00
# No more Improvements found after 9 iterations!
# ran 10 iterations
# Score: 7042.000124738152
# Testing with k 7.00
# No more Improvements found after 6 iterations!
# ran 7 iterations
# Score: 6937.1072076718565
# Testing with k 6.00
# No more Improvements found after 6 iterations!
# ran 7 iterations
# Score: 7254.007255501037
# Testing with k 5.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 6884.000170487637
# Testing with k 4.00
# No more Improvements found after 6 iterations!
# ran 7 iterations
# Score: 6599.007101553973
# Testing with k 3.00
# No more Improvements found after 7 iterations!
# ran 8 iterations
# Score: 6364.017059459459
# Testing with k 2.00
# No more Improvements found after 5 iterations!
# ran 6 iterations
# Score: 5259.025313646503
# Testing with k 1.00
# No more Improvements found after 3 iterations!
# ran 4 iterations
# Score: 5034.016176985923

# %% [markdown]
# **Actually, we can see that this GRASP version is much worse than our initial one!!**

# %% [markdown]
# ## Subtask 8: implement one of the following metaheuristics ... : Simulated Annealing (SA)
# We are going to choose Simulated Annealing because we like it. It will probably take some effort to fine-tune it in order to find the best parameters.

# %%
def simulated_annealing(instance, routes, T_init, alpha=0.95, max_it = 100):
    x = State.from_routes(instance, routes)
    i = 0
    t = 0
    T = T_init
    last_improvements = deque(maxlen=100) # 1000
    last_improvements.append(True)
    scores = []  # Collect scores in each 1000-iteration block
    print("starting SA")
    while any(last_improvements) and T > 1 and i < max_it:
        i += 1
        accepted_random_moves = 0
        block_scores = []  # Scores for this block
        while t < 100:
            neighborhood = RelocateRandomly(instance)
            random_neighbour = next(neighborhood.neighbors(x))
            diff = abs(random_neighbour.score - x.score)
            if random_neighbour.score < x.score:
                x = random_neighbour
                last_improvements.append(True)
            else:
                if random.random() < math.exp(-abs(random_neighbour.score - x.score) / T):
                    x = random_neighbour
                    accepted_random_moves += 1
                last_improvements.append(False)
            block_scores.append(x.score)  # Record score after each move
            t += 1

        # Compute stats after 100 inner iterations
        best_score = min(block_scores)
        worst_score = max(block_scores)
        mean_score = sum(block_scores) / len(block_scores)
        print(f"Acceptance of random moves: {accepted_random_moves / 10} %, Temperature: {T}")
        print(f"Best score: {best_score:.4f}, Worst score: {worst_score:.4f}, Mean score: {mean_score:.4f}")
        T = alpha * T
        t = 0
    return x.routes

# %%
instance = Instance("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
#routes = nearest_neighbor_heuristic(instance)
routes = beam_search(instance, 50)
print("initial objective_score = ", objective_function(instance, routes))
routes = simulated_annealing(instance, routes, 15, alpha = 0.95, max_it=20)
plot_routes(instance, routes)
# Out:
# initial objective_score =  3821.7317828479413
# starting SA
# Acceptance of random moves: 0.2 %, Temperature: 15
# Best score: 3805.7227, Worst score: 3835.4926, Mean score: 3818.6705
# Acceptance of random moves: 0.2 %, Temperature: 14.25
# Best score: 3825.8450, Worst score: 3850.8563, Mean score: 3826.3161

# %% [markdown]
# ## Subtask 9: Use delta evaluation
# Meaning: instead of recompiling an entire function, e.g. the objective function, we only compute the difference the change causes, and add/subtract this value. So let's start by designing a delta evaluated objective function. The delta objective function was moved up to the other delta evaluation, so that it is defined before it is called :)
#
# However, from our (limited) testing experience, delta evaluation is not always faster.
#
# Furthermore, we are asked: Is it possible to pre-process an instance and use derived information later more efficiently?
# Anwser: Yes, by precomputing a distance matrix between all pickup, dropoff, and depot locations, as well as caching route distance sums and squared sums, we can later evaluate routes and delta-objectives more efficiently without recalculating distances repeatedly. However, since we want to focus on experimental tuning right now, we didn't implement this

# %% [markdown]
# ## Subtask 10: Experimental manual tuning
# Now we are asked to perform some experimental manual tuning of relevant algorithmic parameters to find sensible parameter settings for your final experiments. We mainly want to find the best hyperparamters for the Simulated Annealing, namely the initial Temperature T as well as the cooling Schedule variable alpha. For this, We suggest a grid search over the parameter range T = [5, 10, 15, 20, 25, 30] as well as alpha = [0.9, 0.95, 0.98, 0.99]. For each run of the algorithm, we save the time, the final score (objective function, as well as jain fairness).

# %%
# Parameter ranges
T_values = [5, 10, 15, 20, 25, 30]
alpha_values = [0.9, 0.95, 0.98, 0.99]


# Output CSV file
output_file = "misc/sa_grid_search_results.csv"

# Prepare CSV header
with open(output_file, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["T_init", "alpha", "runtime_sec", "final_objective", "final_jain_fairness"])

# Grid search loop
for T_init in T_values:
    for alpha in alpha_values:
        print(f"Running SA with T_init={T_init}, alpha={alpha}")
        # Start timer
        start_time = time.time()

        # Run SA
        initial_routes = nearest_neighbor_heuristic(instance)
        final_routes = simulated_annealing(instance, initial_routes, T_init, alpha)

        # End timer
        end_time = time.time()
        runtime = end_time - start_time

        # Compute final scores
        final_obj = objective_function(instance, final_routes)
        final_jain = get_Jain_fairness(instance, final_routes)

        # Save to CSV
        with open(output_file, "a", newline="") as f:
            writer = csv.writer(f)
            writer.writerow([T_init, alpha, runtime, final_obj, final_jain])

        print(f"Done: runtime={runtime:.2f}s, objective={final_obj:.4f}, Jain={final_jain:.4f}\n")
# Out:
# Running SA with T_init=5, alpha=0.9
# Acceptance of random moves: 2.4 %, Temperature: 5
# Best score: 2230.8971, Worst score: 4094.0286, Mean score: 2622.4740
# Acceptance of random moves: 0.8 %, Temperature: 4.5
# Best score: 2047.4533, Worst score: 2249.5752, Mean score: 2109.7267
# Acceptance of random moves: 0.1 %, Temperature: 4.05
# Best score: 2022.4544, Worst score: 2047.4533, Mean score: 2033.3634
# Acceptance of random moves: 0.4 %, Temperature: 3.645
# Best score: 1985.1780, Worst score: 2037.7563, Mean score: 2009.3210
# Acceptance of random moves: 0.3 %, Temperature: 3.2805
# Best score: 1922.0117, Worst score: 1985.1780, Mean score: 1948.9736
# Acceptance of random moves: 0.1 %, Temperature: 2.9524500000000002
# Best score: 1892.3974, Worst score: 1922.0117, Mean score: 1909.1751
# Acceptance of random moves: 0.2 %, Temperature: 2.6572050000000003
# Best score: 1892.3974, Worst score: 1893.3364, Mean score: 1892.7940
# Acceptance of random moves: 0.2 %, Temperature: 2.3914845000000002
# Best score: 1818.0946, Worst score: 1892.5405, Mean score: 1862.9160
# Acceptance of random moves: 0.3 %, Temperature: 2.15233605
# Best score: 1759.6727, Worst score: 1818.2745, Mean score: 1768.0166
# Acceptance of random moves: 0.0 %, Temperature: 1.9371024450000003
# Best score: 1739.8140, Worst score: 1760.6583, Mean score: 1744.4022
# Acceptance of random moves: 0.5 %, Temperature: 1.7433922005000002
# Best score: 1729.6768, Worst score: 1745.6376, Mean score: 1739.0321
# Acceptance of random moves: 0.1 %, Temperature: 1.5690529804500002
# Best score: 1696.2232, Worst score: 1731.6846, Mean score: 1709.9879
# Acceptance of random moves: 0.1 %, Temperature: 1.412147682405
# Best score: 1694.4458, Worst score: 1696.5430, Mean score: 1694.8105
# Acceptance of random moves: 0.0 %, Temperature: 1.2709329141645
# Best score: 1690.5382, Worst score: 1694.4458, Mean score: 1693.3282
# Acceptance of random moves: 0.1 %, Temperature: 1.14383962274805
# Best score: 1687.1552, Worst score: 1694.8617, Mean score: 1694.6867
# Acceptance of random moves: 0.0 %, Temperature: 1.029455660473245
# Best score: 1687.1552, Worst score: 1687.1552, Mean score: 1687.1552
# Done: runtime=50.20s, objective=1687.1552, Jain=0.9555
#
# Running SA with T_init=5, alpha=0.95
# Acceptance of random moves: 1.4 %, Temperature: 5
# Best score: 2179.1700, Worst score: 4151.0361, Mean score: 2525.6892
# Acceptance of random moves: 0.8 %, Temperature: 4.75
# Best score: 1913.4957, Worst score: 2181.3553, Mean score: 2034.0988
# Acceptance of random moves: 0.6 %, Temperature: 4.5125
# Best score: 1763.4915, Worst score: 1929.6246, Mean score: 1843.6940
# Acceptance of random moves: 0.3 %, Temperature: 4.286875
# Best score: 1730.6258, Worst score: 1771.2921, Mean score: 1749.4163
# Acceptance of random moves: 0.5 %, Temperature: 4.07253125
# Best score: 1713.8175, Worst score: 1736.6215, Mean score: 1727.2951
# Acceptance of random moves: 0.5 %, Temperature: 3.8689046874999997
# Best score: 1712.3702, Worst score: 1723.9558, Mean score: 1718.7645
# Acceptance of random moves: 0.1 %, Temperature: 3.6754594531249998
# Best score: 1690.8130, Worst score: 1720.6059, Mean score: 1701.5628
# Acceptance of random moves: 0.3 %, Temperature: 3.4916864804687497
# Best score: 1687.7100, Worst score: 1713.6243, Mean score: 1697.4381
# Acceptance of random moves: 0.3 %, Temperature: 3.317102156445312
# Best score: 1695.6281, Worst score: 1715.7652, Mean score: 1701.5861
# Acceptance of random moves: 0.0 %, Temperature: 3.151247048623046
# Best score: 1685.0507, Worst score: 1705.4518, Mean score: 1697.5782
# Acceptance of random moves: 0.3 %, Temperature: 2.993684696191894
# Best score: 1667.7774, Worst score: 1688.2589, Mean score: 1679.2334
# Acceptance of random moves: 0.1 %, Temperature: 2.844000461382299
# Best score: 1626.6462, Worst score: 1674.0115, Mean score: 1653.8924
# Acceptance of random moves: 0.3 %, Temperature: 2.701800438313184
# Best score: 1611.9107, Worst score: 1626.6462, Mean score: 1621.1713
# Acceptance of random moves: 0.1 %, Temperature: 2.5667104163975245
# Best score: 1614.3602, Worst score: 1629.9800, Mean score: 1617.5628
# Acceptance of random moves: 0.2 %, Temperature: 2.438374895577648
# Best score: 1605.8307, Worst score: 1620.3443, Mean score: 1609.7748
# Acceptance of random moves: 0.0 %, Temperature: 2.3164561507987655
# Best score: 1604.7640, Worst score: 1605.8307, Mean score: 1605.8211
# Acceptance of random moves: 0.4 %, Temperature: 2.200633343258827
# Best score: 1604.7640, Worst score: 1612.1756, Mean score: 1608.6144
# Done: runtime=52.95s, objective=1612.1756, Jain=0.9547
#
# Running SA with T_init=5, alpha=0.98
# Acceptance of random moves: 1.9 %, Temperature: 5
# Best score: 2051.8862, Worst score: 4136.0929, Mean score: 2434.6524
# Acceptance of random moves: 1.2 %, Temperature: 4.9
# Best score: 1969.9947, Worst score: 2056.8386, Mean score: 2028.5436
# Acceptance of random moves: 1.0 %, Temperature: 4.8020000000000005
# Best score: 1895.4474, Worst score: 1973.0085, Mean score: 1933.0071
# Acceptance of random moves: 0.6 %, Temperature: 4.70596
# Best score: 1881.5841, Worst score: 1911.3676, Mean score: 1897.3891
# Acceptance of random moves: 0.7 %, Temperature: 4.6118408
# Best score: 1822.1743, Worst score: 1900.7832, Mean score: 1848.6351
# Acceptance of random moves: 0.4 %, Temperature: 4.519603984000001
# Best score: 1818.4866, Worst score: 1857.7472, Mean score: 1832.8627
# Acceptance of random moves: 0.1 %, Temperature: 4.429211904320001
# Best score: 1778.4957, Worst score: 1852.3893, Mean score: 1818.1728
# Acceptance of random moves: 0.3 %, Temperature: 4.3406276662336
# Best score: 1774.4820, Worst score: 1789.2512, Mean score: 1782.3971
# Acceptance of random moves: 0.1 %, Temperature: 4.253815112908928
# Best score: 1755.8299, Worst score: 1789.2512, Mean score: 1781.3510
# Acceptance of random moves: 0.3 %, Temperature: 4.1687388106507495
# Best score: 1756.6278, Worst score: 1773.4146, Mean score: 1764.1045
# Acceptance of random moves: 0.3 %, Temperature: 4.085364034437735
# Best score: 1749.8373, Worst score: 1773.0204, Mean score: 1760.8510
# Acceptance of random moves: 0.4 %, Temperature: 4.00365675374898
# Best score: 1723.9675, Worst score: 1761.7900, Mean score: 1742.3664
# Acceptance of random moves: 0.1 %, Temperature: 3.9235836186740003
# Best score: 1719.2831, Worst score: 1723.9675, Mean score: 1719.6757
# Acceptance of random moves: 0.3 %, Temperature: 3.8451119463005203
# Best score: 1719.2831, Worst score: 1733.8962, Mean score: 1724.2969
# Acceptance of random moves: 0.3 %, Temperature: 3.7682097073745098
# Best score: 1721.7997, Worst score: 1726.7551, Mean score: 1723.8118
# Acceptance of random moves: 0.5 %, Temperature: 3.6928455132270197
# Best score: 1714.2745, Worst score: 1759.1144, Mean score: 1725.9071
# Acceptance of random moves: 0.6 %, Temperature: 3.6189886029624794
# Best score: 1743.2348, Worst score: 1776.3420, Mean score: 1755.0683
# Acceptance of random moves: 0.4 %, Temperature: 3.5466088309032298
# Best score: 1753.8804, Worst score: 1768.2507, Mean score: 1759.7711
# Acceptance of random moves: 0.4 %, Temperature: 3.475676654285165
# Best score: 1696.1887, Worst score: 1755.5307, Mean score: 1718.9349
# Acceptance of random moves: 0.1 %, Temperature: 3.406163121199462
# Best score: 1694.1851, Worst score: 1697.4263, Mean score: 1695.7554
# Acceptance of random moves: 0.1 %, Temperature: 3.3380398587754727
# Best score: 1692.9073, Worst score: 1695.4230, Mean score: 1694.1424
# Acceptance of random moves: 0.4 %, Temperature: 3.271279061599963
# Best score: 1692.9073, Worst score: 1697.9541, Mean score: 1695.4159
# Acceptance of random moves: 0.2 %, Temperature: 3.205853480367964
# Best score: 1688.4116, Worst score: 1698.8823, Mean score: 1691.4089
# Acceptance of random moves: 0.2 %, Temperature: 3.1417364107606045
# Best score: 1688.4116, Worst score: 1692.9997, Mean score: 1689.7381
# Done: runtime=137.80s, objective=1692.9997, Jain=0.6145
#
# Running SA with T_init=5, alpha=0.99
# Acceptance of random moves: 1.5 %, Temperature: 5
# Best score: 2200.2599, Worst score: 4102.0180, Mean score: 2567.0033
# Acceptance of random moves: 1.2 %, Temperature: 4.95
# Best score: 1932.9996, Worst score: 2200.2599, Mean score: 2092.0178
# Acceptance of random moves: 0.3 %, Temperature: 4.9005
# Best score: 1901.5164, Worst score: 1932.9996, Mean score: 1920.5874
# Acceptance of random moves: 0.4 %, Temperature: 4.851495
# Best score: 1833.1745, Worst score: 1910.0347, Mean score: 1865.4260
# Acceptance of random moves: 0.6 %, Temperature: 4.8029800499999995
# Best score: 1792.9392, Worst score: 1843.2235, Mean score: 1832.7151
# Acceptance of random moves: 0.6 %, Temperature: 4.754950249499999
# Best score: 1675.6895, Worst score: 1792.9392, Mean score: 1729.8892
# Acceptance of random moves: 0.9 %, Temperature: 4.707400747004999
# Best score: 1640.5610, Worst score: 1696.2653, Mean score: 1666.7337
# Acceptance of random moves: 0.3 %, Temperature: 4.660326739534949
# Best score: 1640.1901, Worst score: 1662.7187, Mean score: 1647.6616
# Acceptance of random moves: 0.6 %, Temperature: 4.6137234721396
# Best score: 1627.3184, Worst score: 1641.4809, Mean score: 1636.6222
# Acceptance of random moves: 0.5 %, Temperature: 4.567586237418204
# Best score: 1641.4809, Worst score: 1661.4270, Mean score: 1652.4320
# Acceptance of random moves: 0.3 %, Temperature: 4.521910375044022
# Best score: 1624.2182, Worst score: 1679.3314, Mean score: 1650.7118
# Acceptance of random moves: 0.3 %, Temperature: 4.476691271293581
# Best score: 1624.2182, Worst score: 1632.2309, Mean score: 1625.7963
# Acceptance of random moves: 0.4 %, Temperature: 4.431924358580646
# Best score: 1632.2309, Worst score: 1702.8644, Mean score: 1677.3285
# Acceptance of random moves: 0.6 %, Temperature: 4.387605114994839
# Best score: 1630.2359, Worst score: 1640.2924, Mean score: 1636.9852
# Acceptance of random moves: 0.5 %, Temperature: 4.343729063844891
# Best score: 1630.9234, Worst score: 1657.1935, Mean score: 1648.4307
# Acceptance of random moves: 0.2 %, Temperature: 4.300291773206442
# Best score: 1630.8926, Worst score: 1648.8846, Mean score: 1632.5762
# Acceptance of random moves: 0.1 %, Temperature: 4.2572888554743775
# Best score: 1614.2433, Worst score: 1632.5826, Mean score: 1617.0870
# Acceptance of random moves: 0.3 %, Temperature: 4.214715966919634
# Best score: 1614.3935, Worst score: 1617.2599, Mean score: 1615.4140
# Acceptance of random moves: 0.3 %, Temperature: 4.172568807250438
# Best score: 1607.5766, Worst score: 1617.6392, Mean score: 1613.5051
# Acceptance of random moves: 0.1 %, Temperature: 4.130843119177934
# Best score: 1582.0432, Worst score: 1608.7585, Mean score: 1591.5806
# Acceptance of random moves: 0.2 %, Temperature: 4.089534687986155
# Best score: 1582.0432, Worst score: 1592.3004, Mean score: 1586.3959
# Acceptance of random moves: 0.1 %, Temperature: 4.048639341106293
# Best score: 1586.0662, Worst score: 1603.2968, Mean score: 1593.1997
# Done: runtime=80.77s, objective=1603.2968, Jain=0.9115
#
# Running SA with T_init=10, alpha=0.9
# Acceptance of random moves: 3.4 %, Temperature: 10
# Best score: 2260.8117, Worst score: 4146.0139, Mean score: 2587.1079
# Acceptance of random moves: 2.7 %, Temperature: 9.0
# Best score: 2216.0266, Worst score: 2375.0758, Mean score: 2297.9459
# Acceptance of random moves: 1.4 %, Temperature: 8.1
# Best score: 2096.5219, Worst score: 2247.9717, Mean score: 2179.4245
# Acceptance of random moves: 0.7 %, Temperature: 7.29
# Best score: 1987.6356, Worst score: 2104.0658, Mean score: 2048.5885
# Acceptance of random moves: 0.9 %, Temperature: 6.561
# Best score: 1906.6575, Worst score: 1994.6663, Mean score: 1952.5276
# Acceptance of random moves: 1.3 %, Temperature: 5.9049000000000005
# Best score: 1905.3130, Worst score: 1946.9158, Mean score: 1920.5285
# Acceptance of random moves: 0.9 %, Temperature: 5.3144100000000005
# Best score: 1895.9044, Worst score: 1922.1843, Mean score: 1911.9630
# Acceptance of random moves: 0.5 %, Temperature: 4.7829690000000005
# Best score: 1913.3436, Worst score: 1924.2623, Mean score: 1917.2604
# Acceptance of random moves: 0.2 %, Temperature: 4.3046721
# Best score: 1901.7746, Worst score: 1926.5916, Mean score: 1912.8036
# Acceptance of random moves: 0.3 %, Temperature: 3.8742048900000006
# Best score: 1891.2497, Worst score: 1901.7746, Mean score: 1897.5416
# Acceptance of random moves: 0.1 %, Temperature: 3.4867844010000004
# Best score: 1892.6470, Worst score: 1901.6883, Mean score: 1896.0737
# Acceptance of random moves: 0.1 %, Temperature: 3.1381059609000004
# Best score: 1880.3788, Worst score: 1903.8897, Mean score: 1895.4001
# Acceptance of random moves: 0.2 %, Temperature: 2.82429536481
# Best score: 1880.3788, Worst score: 1885.7015, Mean score: 1884.5081
# Acceptance of random moves: 0.3 %, Temperature: 2.541865828329
# Best score: 1832.9439, Worst score: 1888.3249, Mean score: 1859.5665
# Acceptance of random moves: 0.1 %, Temperature: 2.2876792454961
# Best score: 1821.1963, Worst score: 1835.2452, Mean score: 1828.9739
# Acceptance of random moves: 0.1 %, Temperature: 2.05891132094649
# Best score: 1799.1929, Worst score: 1821.1963, Mean score: 1814.0154
# Acceptance of random moves: 0.0 %, Temperature: 1.853020188851841
# Best score: 1790.6114, Worst score: 1800.5811, Mean score: 1799.8765
# Acceptance of random moves: 0.1 %, Temperature: 1.6677181699666568
# Best score: 1769.3697, Worst score: 1790.6114, Mean score: 1775.1569
# Acceptance of random moves: 0.1 %, Temperature: 1.5009463529699911
# Best score: 1769.3697, Worst score: 1772.0761, Mean score: 1770.7581
# Acceptance of random moves: 0.0 %, Temperature: 1.350851717672992
# Best score: 1769.3697, Worst score: 1769.3697, Mean score: 1769.3697
# Done: runtime=83.05s, objective=1769.3697, Jain=0.7159
#
# Running SA with T_init=10, alpha=0.95
# Acceptance of random moves: 5.4 %, Temperature: 10
# Best score: 2369.6893, Worst score: 4116.0780, Mean score: 2624.4524
# Acceptance of random moves: 3.5 %, Temperature: 9.5
# Best score: 2163.1558, Worst score: 2484.2765, Mean score: 2281.3840
# Acceptance of random moves: 3.0 %, Temperature: 9.025
# Best score: 2070.8202, Worst score: 2240.2800, Mean score: 2136.4699
# Acceptance of random moves: 1.7 %, Temperature: 8.57375
# Best score: 1942.8526, Worst score: 2109.5976, Mean score: 2004.8109
# Acceptance of random moves: 1.5 %, Temperature: 8.1450625
# Best score: 1864.5565, Worst score: 1963.0154, Mean score: 1913.0420
# Acceptance of random moves: 2.2 %, Temperature: 7.737809374999999
# Best score: 1882.7378, Worst score: 1992.2538, Mean score: 1944.7441
# Acceptance of random moves: 1.4 %, Temperature: 7.3509189062499996
# Best score: 1841.4587, Worst score: 1978.0001, Mean score: 1929.2537
# Acceptance of random moves: 1.6 %, Temperature: 6.9833729609374995
# Best score: 1790.2107, Worst score: 1859.1282, Mean score: 1814.2756
# Acceptance of random moves: 1.7 %, Temperature: 6.634204312890624
# Best score: 1818.3288, Worst score: 1893.6069, Mean score: 1849.9463
# Acceptance of random moves: 1.2 %, Temperature: 6.302494097246092
# Best score: 1797.0343, Worst score: 1874.4752, Mean score: 1819.1013
# Acceptance of random moves: 0.9 %, Temperature: 5.987369392383788
# Best score: 1794.6744, Worst score: 1859.0850, Mean score: 1816.4008
# Acceptance of random moves: 0.8 %, Temperature: 5.688000922764598
# Best score: 1775.1039, Worst score: 1819.3191, Mean score: 1791.5233
# Acceptance of random moves: 0.7 %, Temperature: 5.403600876626368
# Best score: 1749.1869, Worst score: 1796.2357, Mean score: 1780.2542
# Acceptance of random moves: 0.0 %, Temperature: 5.133420832795049
# Best score: 1725.1070, Worst score: 1751.2925, Mean score: 1730.3921
# Acceptance of random moves: 0.1 %, Temperature: 4.876749791155296
# Best score: 1704.1690, Worst score: 1725.1070, Mean score: 1709.7937
# Acceptance of random moves: 0.2 %, Temperature: 4.632912301597531
# Best score: 1699.1927, Worst score: 1713.0230, Mean score: 1706.1548
# Acceptance of random moves: 0.4 %, Temperature: 4.401266686517654
# Best score: 1675.0439, Worst score: 1715.2795, Mean score: 1686.5941
# Acceptance of random moves: 0.5 %, Temperature: 4.181203352191771
# Best score: 1675.0439, Worst score: 1696.1250, Mean score: 1684.8059
# Acceptance of random moves: 0.3 %, Temperature: 3.972143184582182
# Best score: 1647.1887, Worst score: 1689.0360, Mean score: 1675.4614
# Acceptance of random moves: 0.0 %, Temperature: 3.7735360253530725
# Best score: 1646.0031, Worst score: 1647.1887, Mean score: 1646.1578
# Acceptance of random moves: 0.2 %, Temperature: 3.584859224085419
# Best score: 1646.0031, Worst score: 1666.0135, Mean score: 1648.6666
# Acceptance of random moves: 0.2 %, Temperature: 3.4056162628811477
# Best score: 1635.0005, Worst score: 1664.0273, Mean score: 1649.4244
# Acceptance of random moves: 0.0 %, Temperature: 3.2353354497370903
# Best score: 1623.0342, Worst score: 1635.0005, Mean score: 1626.4685
# Acceptance of random moves: 0.1 %, Temperature: 3.0735686772502357
# Best score: 1623.0342, Worst score: 1641.0694, Mean score: 1636.7754
# Acceptance of random moves: 0.1 %, Temperature: 2.919890243387724
# Best score: 1615.0529, Worst score: 1634.0930, Mean score: 1618.8631
# Acceptance of random moves: 0.1 %, Temperature: 2.7738957312183374
# Best score: 1615.0044, Worst score: 1617.0345, Mean score: 1615.7639
# Acceptance of random moves: 0.1 %, Temperature: 2.6352009446574205
# Best score: 1615.0323, Worst score: 1625.1675, Mean score: 1620.1383
# Acceptance of random moves: 0.0 %, Temperature: 2.5034408974245492
# Best score: 1620.0267, Worst score: 1620.0267, Mean score: 1620.0267
# Done: runtime=83.61s, objective=1620.0267, Jain=0.9990
#
# Running SA with T_init=10, alpha=0.98
# Acceptance of random moves: 4.7 %, Temperature: 10
# Best score: 2097.7628, Worst score: 4167.1346, Mean score: 2471.8253
# Acceptance of random moves: 2.6 %, Temperature: 9.8
# Best score: 2036.0624, Worst score: 2164.2466, Mean score: 2107.7000
# Acceptance of random moves: 3.3 %, Temperature: 9.604000000000001
# Best score: 1998.1196, Worst score: 2145.0508, Mean score: 2080.0558
# Acceptance of random moves: 1.4 %, Temperature: 9.41192
# Best score: 1945.2927, Worst score: 2098.1354, Mean score: 2000.7742
# Acceptance of random moves: 1.3 %, Temperature: 9.2236816
# Best score: 1887.8018, Worst score: 1976.7891, Mean score: 1936.7011
# Acceptance of random moves: 1.0 %, Temperature: 9.039207968000001
# Best score: 1854.8730, Worst score: 1942.0800, Mean score: 1877.8447
# Acceptance of random moves: 1.6 %, Temperature: 8.858423808640001
# Best score: 1865.2083, Worst score: 1979.8264, Mean score: 1923.2832
# Acceptance of random moves: 2.1 %, Temperature: 8.6812553324672
# Best score: 1903.9396, Worst score: 1997.2886, Mean score: 1959.7726
# Acceptance of random moves: 2.1 %, Temperature: 8.507630225817856
# Best score: 1868.1203, Worst score: 2014.2046, Mean score: 1924.2382
# Acceptance of random moves: 2.0 %, Temperature: 8.337477621301499
# Best score: 1875.4069, Worst score: 1984.1701, Mean score: 1949.9177
# Acceptance of random moves: 1.0 %, Temperature: 8.17072806887547
# Best score: 1870.0971, Worst score: 1981.7464, Mean score: 1924.2478
# Acceptance of random moves: 1.7 %, Temperature: 8.00731350749796
# Best score: 1867.8174, Worst score: 1937.8141, Mean score: 1906.4244
# Acceptance of random moves: 1.0 %, Temperature: 7.847167237348001
# Best score: 1852.0544, Worst score: 1910.3944, Mean score: 1874.1428
# Acceptance of random moves: 1.3 %, Temperature: 7.690223892601041
# Best score: 1807.9328, Worst score: 1869.2153, Mean score: 1829.1312
# Acceptance of random moves: 0.5 %, Temperature: 7.5364194147490196
# Best score: 1801.2159, Worst score: 1879.3352, Mean score: 1832.6776
# Acceptance of random moves: 0.5 %, Temperature: 7.385691026454039
# Best score: 1774.2702, Worst score: 1821.3969, Mean score: 1798.8956
# Acceptance of random moves: 1.0 %, Temperature: 7.237977205924959
# Best score: 1770.4017, Worst score: 1831.2140, Mean score: 1805.9630
# Acceptance of random moves: 0.8 %, Temperature: 7.0932176618064595
# Best score: 1744.1104, Worst score: 1826.1693, Mean score: 1782.2344
# Acceptance of random moves: 1.2 %, Temperature: 6.95135330857033
# Best score: 1744.0077, Worst score: 1799.1496, Mean score: 1775.9793
# Acceptance of random moves: 0.7 %, Temperature: 6.812326242398924
# Best score: 1741.0001, Worst score: 1773.0540, Mean score: 1756.0869
# Acceptance of random moves: 1.2 %, Temperature: 6.676079717550945
# Best score: 1751.0081, Worst score: 1827.0034, Mean score: 1798.1237
# Acceptance of random moves: 0.4 %, Temperature: 6.542558123199926
# Best score: 1713.0015, Worst score: 1752.0304, Mean score: 1724.7341
# Acceptance of random moves: 1.1 %, Temperature: 6.411706960735928
# Best score: 1704.0000, Worst score: 1775.0414, Mean score: 1729.6929
# Acceptance of random moves: 0.4 %, Temperature: 6.283472821521209
# Best score: 1649.0211, Worst score: 1706.0388, Mean score: 1664.2037
# Acceptance of random moves: 0.5 %, Temperature: 6.157803365090785
# Best score: 1650.0098, Worst score: 1698.2883, Mean score: 1674.6304
# Acceptance of random moves: 0.5 %, Temperature: 6.034647297788969
# Best score: 1689.0076, Worst score: 1732.0423, Mean score: 1698.9284
# Acceptance of random moves: 0.6 %, Temperature: 5.91395435183319
# Best score: 1680.0502, Worst score: 1705.2828, Mean score: 1694.9646
# Acceptance of random moves: 0.2 %, Temperature: 5.795675264796526
# Best score: 1662.0038, Worst score: 1699.0011, Mean score: 1677.6483
# Acceptance of random moves: 0.8 %, Temperature: 5.679761759500596
# Best score: 1671.0027, Worst score: 1706.0627, Mean score: 1680.8195
# Acceptance of random moves: 0.4 %, Temperature: 5.566166524310584
# Best score: 1640.0499, Worst score: 1671.0027, Mean score: 1652.0473
# Acceptance of random moves: 0.8 %, Temperature: 5.454843193824373
# Best score: 1640.0499, Worst score: 1711.6908, Mean score: 1679.9324
# Acceptance of random moves: 0.4 %, Temperature: 5.345746329947885
# Best score: 1671.8363, Worst score: 1695.1328, Mean score: 1686.5452
# Acceptance of random moves: 0.5 %, Temperature: 5.238831403348927
# Best score: 1675.4887, Worst score: 1702.9059, Mean score: 1685.4736
# Acceptance of random moves: 0.7 %, Temperature: 5.134054775281948
# Best score: 1618.4339, Worst score: 1696.4574, Mean score: 1653.2808
# Acceptance of random moves: 0.1 %, Temperature: 5.0313736797763084
# Best score: 1615.0096, Worst score: 1620.8460, Mean score: 1619.3970
# Acceptance of random moves: 0.2 %, Temperature: 4.930746206180782
# Best score: 1615.9067, Worst score: 1634.6457, Mean score: 1629.3864
# Done: runtime=109.93s, objective=1634.6457, Jain=0.8980
#
# Running SA with T_init=10, alpha=0.99
# Acceptance of random moves: 3.8 %, Temperature: 10
# Best score: 2136.0263, Worst score: 4157.1265, Mean score: 2489.1881
# Acceptance of random moves: 2.5 %, Temperature: 9.9
# Best score: 1996.5194, Worst score: 2157.2060, Mean score: 2049.1261
# Acceptance of random moves: 2.0 %, Temperature: 9.801
# Best score: 1905.5256, Worst score: 2051.0819, Mean score: 1970.7062
# Acceptance of random moves: 1.5 %, Temperature: 9.70299
# Best score: 1949.3548, Worst score: 2047.7839, Mean score: 1992.0323
# Acceptance of random moves: 1.6 %, Temperature: 9.605960099999999
# Best score: 1978.4285, Worst score: 2127.0936, Mean score: 2041.6756
# Acceptance of random moves: 1.4 %, Temperature: 9.509900498999999
# Best score: 1943.3720, Worst score: 2085.9773, Mean score: 2009.2100
# Acceptance of random moves: 1.2 %, Temperature: 9.414801494009998
# Best score: 1952.4131, Worst score: 2022.1289, Mean score: 1970.5550
# Acceptance of random moves: 1.8 %, Temperature: 9.320653479069898
# Best score: 1905.2026, Worst score: 2022.1289, Mean score: 1970.1492
# Acceptance of random moves: 1.5 %, Temperature: 9.2274469442792
# Best score: 1886.8165, Worst score: 1970.5209, Mean score: 1924.6170
# Acceptance of random moves: 2.3 %, Temperature: 9.135172474836407
# Best score: 1897.0363, Worst score: 2032.8412, Mean score: 1986.3742
# Acceptance of random moves: 2.8 %, Temperature: 9.043820750088043
# Best score: 1984.7112, Worst score: 2127.1200, Mean score: 2063.5589
# Acceptance of random moves: 1.3 %, Temperature: 8.953382542587162
# Best score: 1947.3299, Worst score: 2097.1749, Mean score: 2006.1717
# Acceptance of random moves: 1.6 %, Temperature: 8.863848717161291
# Best score: 1850.3407, Worst score: 2033.6875, Mean score: 1934.4916
# Acceptance of random moves: 1.3 %, Temperature: 8.775210229989678
# Best score: 1871.1580, Worst score: 1941.8525, Mean score: 1883.0143
# Acceptance of random moves: 1.4 %, Temperature: 8.687458127689782
# Best score: 1885.3091, Worst score: 1979.1273, Mean score: 1919.6884
# Acceptance of random moves: 1.7 %, Temperature: 8.600583546412883
# Best score: 1869.3577, Worst score: 1974.6723, Mean score: 1925.0217
# Acceptance of random moves: 1.9 %, Temperature: 8.514577710948755
# Best score: 1867.4533, Worst score: 1913.3728, Mean score: 1887.4064
# Acceptance of random moves: 1.3 %, Temperature: 8.429431933839268
# Best score: 1799.9617, Worst score: 1909.2162, Mean score: 1834.2370
# Acceptance of random moves: 1.5 %, Temperature: 8.345137614500876
# Best score: 1798.5887, Worst score: 1896.0416, Mean score: 1836.1270
# Acceptance of random moves: 0.8 %, Temperature: 8.261686238355868
# Best score: 1781.4741, Worst score: 1860.8009, Mean score: 1812.5971
# Acceptance of random moves: 0.7 %, Temperature: 8.17906937597231
# Best score: 1746.0370, Worst score: 1803.0780, Mean score: 1788.0030
# Acceptance of random moves: 0.6 %, Temperature: 8.097278682212586
# Best score: 1780.0012, Worst score: 1818.0264, Mean score: 1794.6545
# Acceptance of random moves: 1.6 %, Temperature: 8.01630589539046
# Best score: 1766.0430, Worst score: 1858.0368, Mean score: 1809.6915
# Acceptance of random moves: 1.2 %, Temperature: 7.936142836436555
# Best score: 1763.1257, Worst score: 1841.0215, Mean score: 1788.1817
# Acceptance of random moves: 1.5 %, Temperature: 7.856781408072189
# Best score: 1783.2098, Worst score: 1869.0164, Mean score: 1828.2221
# Acceptance of random moves: 1.1 %, Temperature: 7.778213593991468
# Best score: 1731.0987, Worst score: 1858.1957, Mean score: 1818.0480
# Acceptance of random moves: 1.2 %, Temperature: 7.700431458051553
# Best score: 1706.0688, Worst score: 1821.8200, Mean score: 1784.0581
# Acceptance of random moves: 1.2 %, Temperature: 7.623427143471037
# Best score: 1743.4866, Worst score: 1831.1270, Mean score: 1776.1445
# Acceptance of random moves: 1.3 %, Temperature: 7.547192872036327
# Best score: 1782.0900, Worst score: 1854.0694, Mean score: 1815.3479
# Acceptance of random moves: 1.3 %, Temperature: 7.4717209433159635
# Best score: 1787.4048, Worst score: 1880.0247, Mean score: 1844.4153
# Acceptance of random moves: 0.9 %, Temperature: 7.397003733882804
# Best score: 1709.0702, Worst score: 1787.4048, Mean score: 1738.8950
# Acceptance of random moves: 0.7 %, Temperature: 7.323033696543976
# Best score: 1698.1904, Worst score: 1782.0020, Mean score: 1731.5606
# Acceptance of random moves: 0.4 %, Temperature: 7.249803359578536
# Best score: 1688.0907, Worst score: 1717.4078, Mean score: 1700.6195
# Acceptance of random moves: 0.6 %, Temperature: 7.177305325982751
# Best score: 1656.1099, Worst score: 1738.1488, Mean score: 1708.7808
# Acceptance of random moves: 1.1 %, Temperature: 7.105532272722923
# Best score: 1702.3464, Worst score: 1764.4949, Mean score: 1729.3669
# Acceptance of random moves: 1.7 %, Temperature: 7.034476949995693
# Best score: 1655.5294, Worst score: 1806.1513, Mean score: 1716.6435
# Acceptance of random moves: 1.0 %, Temperature: 6.964132180495737
# Best score: 1697.3290, Worst score: 1778.3370, Mean score: 1731.5295
# Acceptance of random moves: 0.6 %, Temperature: 6.894490858690779
# Best score: 1731.3132, Worst score: 1776.5993, Mean score: 1756.7654
# Acceptance of random moves: 0.8 %, Temperature: 6.825545950103871
# Best score: 1751.6381, Worst score: 1813.3081, Mean score: 1765.3397
# Acceptance of random moves: 1.5 %, Temperature: 6.757290490602832
# Best score: 1776.3145, Worst score: 1850.7008, Mean score: 1807.0126
# Acceptance of random moves: 1.3 %, Temperature: 6.689717585696804
# Best score: 1771.1598, Worst score: 1845.7088, Mean score: 1793.9078
# Acceptance of random moves: 0.9 %, Temperature: 6.622820409839836
# Best score: 1773.2680, Worst score: 1819.4910, Mean score: 1798.4926
# Acceptance of random moves: 1.2 %, Temperature: 6.556592205741437
# Best score: 1790.8456, Worst score: 1844.3100, Mean score: 1819.1648
# Acceptance of random moves: 1.7 %, Temperature: 6.491026283684023
# Best score: 1812.6464, Worst score: 1885.3601, Mean score: 1847.7751
# Acceptance of random moves: 0.9 %, Temperature: 6.426116020847182
# Best score: 1780.5403, Worst score: 1840.9182, Mean score: 1803.0058
# Acceptance of random moves: 0.8 %, Temperature: 6.361854860638711
# Best score: 1739.2013, Worst score: 1799.8642, Mean score: 1763.0923
# Acceptance of random moves: 0.9 %, Temperature: 6.298236312032324
# Best score: 1739.2013, Worst score: 1775.1771, Mean score: 1750.1195
# Acceptance of random moves: 0.2 %, Temperature: 6.235253948912001
# Best score: 1764.1456, Worst score: 1775.8288, Mean score: 1769.5932
# Acceptance of random moves: 0.4 %, Temperature: 6.172901409422881
# Best score: 1742.0797, Worst score: 1782.3799, Mean score: 1749.6267
# Acceptance of random moves: 0.6 %, Temperature: 6.111172395328652
# Best score: 1724.8586, Worst score: 1757.2122, Mean score: 1741.7363
# Acceptance of random moves: 0.7 %, Temperature: 6.050060671375365
# Best score: 1703.1084, Worst score: 1759.3555, Mean score: 1727.9061
# Acceptance of random moves: 0.7 %, Temperature: 5.989560064661611
# Best score: 1713.1639, Worst score: 1737.2671, Mean score: 1725.7648
# Acceptance of random moves: 0.4 %, Temperature: 5.929664464014995
# Best score: 1708.7041, Worst score: 1764.3798, Mean score: 1751.3142
# Acceptance of random moves: 0.5 %, Temperature: 5.870367819374845
# Best score: 1707.3150, Worst score: 1721.3904, Mean score: 1713.7661
# Acceptance of random moves: 1.0 %, Temperature: 5.8116641411810965
# Best score: 1691.2767, Worst score: 1773.5084, Mean score: 1722.8313
# Acceptance of random moves: 0.2 %, Temperature: 5.753547499769286
# Best score: 1649.8064, Worst score: 1721.9646, Mean score: 1665.1674
# Acceptance of random moves: 0.1 %, Temperature: 5.696012024771592
# Best score: 1625.7720, Worst score: 1649.8064, Mean score: 1631.1455
# Acceptance of random moves: 0.5 %, Temperature: 5.6390519045238765
# Best score: 1630.6868, Worst score: 1672.8860, Mean score: 1645.8128
# Acceptance of random moves: 0.7 %, Temperature: 5.582661385478637
# Best score: 1639.8837, Worst score: 1700.2235, Mean score: 1665.6241
# Acceptance of random moves: 0.2 %, Temperature: 5.526834771623851
# Best score: 1639.8837, Worst score: 1653.4269, Mean score: 1641.0706
# Acceptance of random moves: 0.5 %, Temperature: 5.471566423907612
# Best score: 1639.4221, Worst score: 1666.3792, Mean score: 1655.6997
# Acceptance of random moves: 0.2 %, Temperature: 5.416850759668536
# Best score: 1633.7099, Worst score: 1656.7436, Mean score: 1639.7281
# Acceptance of random moves: 0.3 %, Temperature: 5.362682252071851
# Best score: 1627.9772, Worst score: 1661.7509, Mean score: 1634.3528
# Acceptance of random moves: 0.4 %, Temperature: 5.309055429551132
# Best score: 1627.9772, Worst score: 1647.4726, Mean score: 1637.2271
# Acceptance of random moves: 0.4 %, Temperature: 5.2559648752556205
# Best score: 1642.3337, Worst score: 1662.0565, Mean score: 1649.4457
# Done: runtime=270.32s, objective=1662.0565, Jain=0.5738
#
# Running SA with T_init=15, alpha=0.9
# Acceptance of random moves: 7.7 %, Temperature: 15
# Best score: 2525.1765, Worst score: 4143.0173, Mean score: 2809.0126
# Acceptance of random moves: 4.6 %, Temperature: 13.5
# Best score: 2372.5221, Worst score: 2645.1080, Mean score: 2476.5041
# Acceptance of random moves: 4.4 %, Temperature: 12.15
# Best score: 2123.2429, Worst score: 2410.5553, Mean score: 2240.8225
# Acceptance of random moves: 4.3 %, Temperature: 10.935
# Best score: 1947.9700, Worst score: 2169.7195, Mean score: 2034.9319
# Acceptance of random moves: 2.8 %, Temperature: 9.8415
# Best score: 1878.3727, Worst score: 2108.4784, Mean score: 1994.8470
# Acceptance of random moves: 1.8 %, Temperature: 8.85735
# Best score: 1843.2363, Worst score: 1969.9938, Mean score: 1905.0724
# Acceptance of random moves: 0.9 %, Temperature: 7.971615000000001
# Best score: 1795.0161, Worst score: 1969.8527, Mean score: 1851.7985
# Acceptance of random moves: 0.5 %, Temperature: 7.174453500000001
# Best score: 1746.8647, Worst score: 1828.1674, Mean score: 1805.3886
# Acceptance of random moves: 1.1 %, Temperature: 6.457008150000001
# Best score: 1699.0868, Worst score: 1776.7781, Mean score: 1747.3397
# Acceptance of random moves: 0.7 %, Temperature: 5.811307335000001
# Best score: 1730.3617, Worst score: 1758.7606, Mean score: 1751.0345
# Acceptance of random moves: 0.5 %, Temperature: 5.230176601500001
# Best score: 1701.5666, Worst score: 1758.7606, Mean score: 1724.2537
# Acceptance of random moves: 0.4 %, Temperature: 4.707158941350001
# Best score: 1646.4639, Worst score: 1713.1872, Mean score: 1672.7051
# Acceptance of random moves: 0.5 %, Temperature: 4.236443047215001
# Best score: 1624.0224, Worst score: 1674.2959, Mean score: 1653.9253
# Acceptance of random moves: 0.2 %, Temperature: 3.8127987424935013
# Best score: 1624.0224, Worst score: 1630.1511, Mean score: 1627.6066
# Acceptance of random moves: 0.5 %, Temperature: 3.4315188682441513
# Best score: 1622.2525, Worst score: 1637.7718, Mean score: 1628.5657
# Acceptance of random moves: 0.3 %, Temperature: 3.0883669814197363
# Best score: 1628.9278, Worst score: 1649.8357, Mean score: 1642.6802
# Acceptance of random moves: 0.0 %, Temperature: 2.779530283277763
# Best score: 1629.1636, Worst score: 1631.3073, Mean score: 1629.4530
# Acceptance of random moves: 0.0 %, Temperature: 2.5015772549499866
# Best score: 1606.4040, Worst score: 1629.1636, Mean score: 1617.7694
# Acceptance of random moves: 0.1 %, Temperature: 2.251419529454988
# Best score: 1581.5858, Worst score: 1609.8538, Mean score: 1586.7055
# Acceptance of random moves: 0.0 %, Temperature: 2.0262775765094894
# Best score: 1581.5858, Worst score: 1581.5858, Mean score: 1581.5858
# Done: runtime=84.39s, objective=1581.5858, Jain=0.8618
#
# Running SA with T_init=15, alpha=0.95
# Acceptance of random moves: 7.0 %, Temperature: 15
# Best score: 2258.3315, Worst score: 4122.0016, Mean score: 2771.4231
# Acceptance of random moves: 4.6 %, Temperature: 14.25
# Best score: 2242.3136, Worst score: 2433.1009, Mean score: 2340.7367
# Acceptance of random moves: 5.0 %, Temperature: 13.5375
# Best score: 2150.8726, Worst score: 2455.9280, Mean score: 2288.9877
# Acceptance of random moves: 4.4 %, Temperature: 12.860624999999999
# Best score: 2090.0910, Worst score: 2363.8731, Mean score: 2234.8590
# Acceptance of random moves: 4.8 %, Temperature: 12.217593749999999
# Best score: 2151.6245, Worst score: 2411.5504, Mean score: 2291.3386
# Acceptance of random moves: 3.9 %, Temperature: 11.606714062499998
# Best score: 2021.1292, Worst score: 2249.0230, Mean score: 2167.8958
# Acceptance of random moves: 2.9 %, Temperature: 11.026378359374998
# Best score: 1999.4681, Worst score: 2243.1330, Mean score: 2110.5317
# Acceptance of random moves: 1.9 %, Temperature: 10.475059441406248
# Best score: 1955.0561, Worst score: 2172.1543, Mean score: 2039.0694
# Acceptance of random moves: 1.7 %, Temperature: 9.951306469335936
# Best score: 1899.0543, Worst score: 2066.3568, Mean score: 1966.6041
# Acceptance of random moves: 3.4 %, Temperature: 9.453741145869138
# Best score: 1877.4847, Worst score: 2011.2592, Mean score: 1935.1697
# Acceptance of random moves: 2.0 %, Temperature: 8.98105408857568
# Best score: 1746.2160, Worst score: 1901.0002, Mean score: 1825.4916
# Acceptance of random moves: 1.0 %, Temperature: 8.532001384146897
# Best score: 1753.0004, Worst score: 1846.1442, Mean score: 1795.5046
# Acceptance of random moves: 1.3 %, Temperature: 8.105401314939552
# Best score: 1779.0707, Worst score: 1887.0021, Mean score: 1820.3138
# Acceptance of random moves: 1.0 %, Temperature: 7.700131249192574
# Best score: 1722.1172, Worst score: 1813.1004, Mean score: 1784.9140
# Acceptance of random moves: 1.4 %, Temperature: 7.315124686732945
# Best score: 1752.2308, Worst score: 1866.4431, Mean score: 1814.2452
# Acceptance of random moves: 0.9 %, Temperature: 6.949368452396298
# Best score: 1733.2738, Worst score: 1855.3476, Mean score: 1778.9121
# Acceptance of random moves: 0.8 %, Temperature: 6.601900029776483
# Best score: 1647.2766, Worst score: 1733.5083, Mean score: 1695.3354
# Acceptance of random moves: 1.0 %, Temperature: 6.271805028287659
# Best score: 1660.8525, Worst score: 1725.1398, Mean score: 1689.9289
# Acceptance of random moves: 0.7 %, Temperature: 5.958214776873276
# Best score: 1648.1193, Worst score: 1715.2048, Mean score: 1666.1732
# Acceptance of random moves: 0.3 %, Temperature: 5.6603040380296115
# Best score: 1668.0233, Worst score: 1684.0374, Mean score: 1675.8284
# Acceptance of random moves: 0.3 %, Temperature: 5.37728883612813
# Best score: 1674.0270, Worst score: 1702.1283, Mean score: 1682.0855
# Done: runtime=64.58s, objective=1702.1283, Jain=0.9951
#
# Running SA with T_init=15, alpha=0.98
# Acceptance of random moves: 6.6 %, Temperature: 15
# Best score: 2351.3845, Worst score: 4143.0173, Mean score: 2727.0042
# Acceptance of random moves: 3.5 %, Temperature: 14.7
# Best score: 2099.1788, Worst score: 2467.8974, Mean score: 2232.3429
# Acceptance of random moves: 5.6 %, Temperature: 14.405999999999999
# Best score: 2243.6366, Worst score: 2493.2815, Mean score: 2376.3232
# Acceptance of random moves: 6.0 %, Temperature: 14.117879999999998
# Best score: 2121.3257, Worst score: 2532.2054, Mean score: 2355.7538
# Acceptance of random moves: 3.9 %, Temperature: 13.835522399999997
# Best score: 2164.1307, Worst score: 2354.9187, Mean score: 2256.7658
# Acceptance of random moves: 4.3 %, Temperature: 13.558811951999997
# Best score: 2126.0693, Worst score: 2371.0195, Mean score: 2243.9865
# Acceptance of random moves: 3.6 %, Temperature: 13.287635712959997
# Best score: 2087.0057, Worst score: 2246.0252, Mean score: 2155.2387
# Acceptance of random moves: 3.6 %, Temperature: 13.021882998700796
# Best score: 2153.4780, Worst score: 2336.0183, Mean score: 2224.0573
# Acceptance of random moves: 4.5 %, Temperature: 12.76144533872678
# Best score: 2064.0583, Worst score: 2327.1117, Mean score: 2205.7437
# Acceptance of random moves: 5.4 %, Temperature: 12.506216431952245
# Best score: 2212.6025, Worst score: 2374.4652, Mean score: 2296.2000
# Acceptance of random moves: 5.0 %, Temperature: 12.2560921033132
# Best score: 2148.1808, Worst score: 2318.3642, Mean score: 2225.1568
# Acceptance of random moves: 3.0 %, Temperature: 12.010970261246936
# Best score: 2132.2082, Worst score: 2315.4135, Mean score: 2210.4476
# Acceptance of random moves: 4.3 %, Temperature: 11.770750856021996
# Best score: 2107.8921, Worst score: 2332.8960, Mean score: 2199.8730
# Acceptance of random moves: 2.6 %, Temperature: 11.535335838901556
# Best score: 2010.1081, Worst score: 2276.7955, Mean score: 2089.4970
# Acceptance of random moves: 4.6 %, Temperature: 11.304629122123524
# Best score: 2010.5727, Worst score: 2342.6662, Mean score: 2145.1716
# Acceptance of random moves: 3.6 %, Temperature: 11.078536539681053
# Best score: 2089.7792, Worst score: 2236.7079, Mean score: 2174.5686
# Acceptance of random moves: 2.2 %, Temperature: 10.856965808887432
# Best score: 2058.9141, Worst score: 2227.9164, Mean score: 2150.5286
# Acceptance of random moves: 2.4 %, Temperature: 10.639826492709684
# Best score: 2053.7587, Worst score: 2139.2354, Mean score: 2093.7686
# Acceptance of random moves: 2.3 %, Temperature: 10.42702996285549
# Best score: 2077.7722, Worst score: 2171.0886, Mean score: 2125.9709
# Acceptance of random moves: 2.1 %, Temperature: 10.21848936359838
# Best score: 2057.9181, Worst score: 2220.3161, Mean score: 2135.8490
# Acceptance of random moves: 4.2 %, Temperature: 10.014119576326411
# Best score: 2069.3211, Worst score: 2202.7005, Mean score: 2137.2590
# Acceptance of random moves: 2.1 %, Temperature: 9.813837184799883
# Best score: 2027.6583, Worst score: 2175.8115, Mean score: 2105.4996
# Acceptance of random moves: 3.1 %, Temperature: 9.617560441103885
# Best score: 2004.8081, Worst score: 2138.7165, Mean score: 2081.5860
# Acceptance of random moves: 2.0 %, Temperature: 9.425209232281807
# Best score: 1957.5466, Worst score: 2126.2860, Mean score: 2048.1593
# Acceptance of random moves: 2.2 %, Temperature: 9.236705047636171
# Best score: 1881.2234, Worst score: 2017.1161, Mean score: 1973.6520
# Acceptance of random moves: 1.9 %, Temperature: 9.051970946683447
# Best score: 1904.6676, Worst score: 1999.2331, Mean score: 1957.3688
# Acceptance of random moves: 1.8 %, Temperature: 8.870931527749779
# Best score: 1813.8012, Worst score: 2029.9134, Mean score: 1862.1850
# Acceptance of random moves: 2.0 %, Temperature: 8.693512897194783
# Best score: 1830.9212, Worst score: 1902.4095, Mean score: 1871.7077
# Acceptance of random moves: 1.9 %, Temperature: 8.519642639250886
# Best score: 1849.0497, Worst score: 1944.7612, Mean score: 1885.7492
# Acceptance of random moves: 0.8 %, Temperature: 8.349249786465869
# Best score: 1802.3947, Worst score: 1868.7947, Mean score: 1828.5813
# Acceptance of random moves: 1.6 %, Temperature: 8.182264790736552
# Best score: 1794.1661, Worst score: 1882.6046, Mean score: 1836.4151
# Acceptance of random moves: 1.1 %, Temperature: 8.01861949492182
# Best score: 1803.9998, Worst score: 1902.0597, Mean score: 1834.4081
# Acceptance of random moves: 1.2 %, Temperature: 7.858247105023383
# Best score: 1786.7834, Worst score: 1878.1540, Mean score: 1813.1928
# Acceptance of random moves: 0.8 %, Temperature: 7.701082162922916
# Best score: 1752.4395, Worst score: 1820.7314, Mean score: 1788.7662
# Acceptance of random moves: 1.5 %, Temperature: 7.547060519664457
# Best score: 1805.0910, Worst score: 1918.7458, Mean score: 1865.6112
# Acceptance of random moves: 2.1 %, Temperature: 7.396119309271168
# Best score: 1805.0910, Worst score: 1953.5306, Mean score: 1864.1388
# Acceptance of random moves: 0.5 %, Temperature: 7.248196923085745
# Best score: 1787.8349, Worst score: 1944.5668, Mean score: 1818.3009
# Acceptance of random moves: 1.0 %, Temperature: 7.10323298462403
# Best score: 1766.1966, Worst score: 1818.3945, Mean score: 1794.9953
# Acceptance of random moves: 1.5 %, Temperature: 6.961168324931549
# Best score: 1717.6160, Worst score: 1812.1283, Mean score: 1757.3161
# Acceptance of random moves: 1.1 %, Temperature: 6.821944958432918
# Best score: 1746.5939, Worst score: 1782.5835, Mean score: 1764.6351
# Acceptance of random moves: 0.4 %, Temperature: 6.6855060592642594
# Best score: 1689.6292, Worst score: 1782.5835, Mean score: 1711.2212
# Acceptance of random moves: 0.4 %, Temperature: 6.551795938078974
# Best score: 1689.5560, Worst score: 1722.8644, Mean score: 1695.2465
# Acceptance of random moves: 0.7 %, Temperature: 6.420760019317394
# Best score: 1687.8688, Worst score: 1716.8304, Mean score: 1698.2658
# Acceptance of random moves: 0.5 %, Temperature: 6.2923448189310465
# Best score: 1683.4758, Worst score: 1728.3037, Mean score: 1695.8559
# Acceptance of random moves: 0.5 %, Temperature: 6.166497922552425
# Best score: 1698.5473, Worst score: 1747.9670, Mean score: 1715.4261
# Acceptance of random moves: 0.6 %, Temperature: 6.043167964101377
# Best score: 1713.0062, Worst score: 1740.3186, Mean score: 1726.9232
# Acceptance of random moves: 0.6 %, Temperature: 5.922304604819349
# Best score: 1708.1619, Worst score: 1744.0292, Mean score: 1728.7161
# Acceptance of random moves: 0.6 %, Temperature: 5.803858512722962
# Best score: 1730.0008, Worst score: 1772.3527, Mean score: 1749.4910
# Acceptance of random moves: 0.6 %, Temperature: 5.687781342468503
# Best score: 1727.2362, Worst score: 1777.7562, Mean score: 1755.0069
# Acceptance of random moves: 0.9 %, Temperature: 5.574025715619133
# Best score: 1708.3838, Worst score: 1759.5321, Mean score: 1732.8969
# Acceptance of random moves: 0.3 %, Temperature: 5.4625452013067495
# Best score: 1708.3838, Worst score: 1730.8235, Mean score: 1723.2192
# Acceptance of random moves: 1.0 %, Temperature: 5.353294297280614
# Best score: 1700.6233, Worst score: 1735.2586, Mean score: 1722.6446
# Acceptance of random moves: 0.3 %, Temperature: 5.246228411335002
# Best score: 1645.3011, Worst score: 1700.6233, Mean score: 1659.9265
# Acceptance of random moves: 0.5 %, Temperature: 5.141303843108302
# Best score: 1635.6921, Worst score: 1673.1127, Mean score: 1656.6581
# Acceptance of random moves: 0.6 %, Temperature: 5.038477766246136
# Best score: 1637.9170, Worst score: 1668.1742, Mean score: 1656.8998
# Acceptance of random moves: 0.0 %, Temperature: 4.937708210921214
# Best score: 1609.6910, Worst score: 1659.3285, Mean score: 1627.9218
# Acceptance of random moves: 0.2 %, Temperature: 4.838954046702789
# Best score: 1609.3493, Worst score: 1619.6249, Mean score: 1609.4442
# Acceptance of random moves: 0.2 %, Temperature: 4.742174965768734
# Best score: 1592.1904, Worst score: 1619.6249, Mean score: 1595.8558
# Acceptance of random moves: 0.0 %, Temperature: 4.647331466453359
# Best score: 1579.7931, Worst score: 1597.8452, Mean score: 1594.8312
# Acceptance of random moves: 0.5 %, Temperature: 4.554384837124291
# Best score: 1579.7931, Worst score: 1620.0075, Mean score: 1593.2207
# Acceptance of random moves: 0.5 %, Temperature: 4.463297140381806
# Best score: 1620.0075, Worst score: 1655.6799, Mean score: 1634.9829
# Acceptance of random moves: 0.5 %, Temperature: 4.374031197574169
# Best score: 1626.5876, Worst score: 1644.8565, Mean score: 1638.3969
# Acceptance of random moves: 0.2 %, Temperature: 4.286550573622685
# Best score: 1618.1528, Worst score: 1643.2404, Mean score: 1624.4457
# Acceptance of random moves: 0.2 %, Temperature: 4.200819562150231
# Best score: 1601.8288, Worst score: 1624.9918, Mean score: 1613.8349
# Acceptance of random moves: 0.2 %, Temperature: 4.116803170907227
# Best score: 1582.7600, Worst score: 1606.8244, Mean score: 1597.4765
# Acceptance of random moves: 0.5 %, Temperature: 4.034467107489083
# Best score: 1576.9308, Worst score: 1619.8999, Mean score: 1592.0404
# Acceptance of random moves: 0.2 %, Temperature: 3.953777765339301
# Best score: 1597.6802, Worst score: 1603.9939, Mean score: 1599.6223
# Acceptance of random moves: 0.3 %, Temperature: 3.874702210032515
# Best score: 1595.7024, Worst score: 1616.4466, Mean score: 1600.2278
# Acceptance of random moves: 0.1 %, Temperature: 3.7972081658318646
# Best score: 1591.4768, Worst score: 1595.7024, Mean score: 1594.0756
# Acceptance of random moves: 0.1 %, Temperature: 3.7212640025152273
# Best score: 1563.2380, Worst score: 1595.7024, Mean score: 1567.9658
# Acceptance of random moves: 0.0 %, Temperature: 3.646838722464923
# Best score: 1541.3439, Worst score: 1565.8837, Mean score: 1555.5963
# Acceptance of random moves: 0.0 %, Temperature: 3.5739019480156244
# Best score: 1541.3439, Worst score: 1541.3439, Mean score: 1541.3439
# Done: runtime=328.41s, objective=1541.3439, Jain=0.7169
#
# Running SA with T_init=15, alpha=0.99
# Acceptance of random moves: 9.5 %, Temperature: 15
# Best score: 2408.6039, Worst score: 4049.0916, Mean score: 2760.0812
# Acceptance of random moves: 8.1 %, Temperature: 14.85
# Best score: 2267.9503, Worst score: 2638.9042, Mean score: 2453.5405
# Acceptance of random moves: 5.1 %, Temperature: 14.7015
# Best score: 2269.7979, Worst score: 2627.6763, Mean score: 2470.5344
# Acceptance of random moves: 5.7 %, Temperature: 14.554485
# Best score: 2255.9366, Worst score: 2646.7602, Mean score: 2426.7652
# Acceptance of random moves: 7.2 %, Temperature: 14.40894015
# Best score: 2129.4452, Worst score: 2608.1957, Mean score: 2341.6390
# Acceptance of random moves: 6.3 %, Temperature: 14.264850748499999
# Best score: 2078.8819, Worst score: 2341.2380, Mean score: 2188.6369
# Acceptance of random moves: 5.9 %, Temperature: 14.122202241015
# Best score: 2104.9700, Worst score: 2360.9263, Mean score: 2189.7981
# Acceptance of random moves: 4.0 %, Temperature: 13.98098021860485
# Best score: 2098.7192, Worst score: 2336.8789, Mean score: 2190.6199
# Acceptance of random moves: 6.2 %, Temperature: 13.841170416418802
# Best score: 2176.0283, Worst score: 2489.7442, Mean score: 2319.2877
# Acceptance of random moves: 4.0 %, Temperature: 13.702758712254614
# Best score: 2175.1414, Worst score: 2465.8620, Mean score: 2277.9406
# Acceptance of random moves: 5.5 %, Temperature: 13.565731125132068
# Best score: 2179.8613, Worst score: 2472.8008, Mean score: 2308.4848
# ...
# Best score: 2273.3980, Worst score: 2730.0775, Mean score: 2432.5395
# Acceptance of random moves: 7.1 %, Temperature: 17.260642499307853
# Best score: 2317.0637, Worst score: 2670.0140, Mean score: 2500.9876
# Acceptance of random moves: 5.0 %, Temperature: 17.088036074314775
# Best score: 2228.3363, Worst score: 2471.1509, Mean score: 2339.8472
# Acceptance of random moves: 5.3 %, Temperature: 16.917155713571628
# Best score: 2236.8200, Worst score: 2552.0006, Mean score: 2409.7706
# Acceptance of random moves: 8.2 %, Temperature: 16.747984156435912
# Best score: 2385.1954, Worst score: 2741.8043, Mean score: 2510.4185
# Acceptance of random moves: 9.7 %, Temperature: 16.580504314871554
# Best score: 2417.0934, Worst score: 2868.1424, Mean score: 2572.5238
# Acceptance of random moves: 8.0 %, Temperature: 16.41469927172284
# Best score: 2229.9700, Worst score: 2550.2563, Mean score: 2382.4022
# Acceptance of random moves: 8.6 %, Temperature: 16.25055227900561
# Best score: 2260.9700, Worst score: 2577.9700, Mean score: 2398.9190
# Acceptance of random moves: 7.2 %, Temperature: 16.088046756215554
# Best score: 2269.9700, Worst score: 2559.9798, Mean score: 2387.8261
# Acceptance of random moves: 7.0 %, Temperature: 15.9271662886534
# Best score: 2242.9700, Worst score: 2496.1102, Mean score: 2351.1339
# Acceptance of random moves: 9.3 %, Temperature: 15.767894625766866
# Best score: 2303.9700, Worst score: 2702.4664, Mean score: 2498.3009
# Acceptance of random moves: 7.8 %, Temperature: 15.610215679509198
# Best score: 2396.7661, Worst score: 2760.4211, Mean score: 2532.2399
# Acceptance of random moves: 7.1 %, Temperature: 15.454113522714106
# Best score: 2194.4789, Worst score: 2638.1662, Mean score: 2396.0098
# Acceptance of random moves: 5.1 %, Temperature: 15.299572387486965
# Best score: 2207.9585, Worst score: 2502.2642, Mean score: 2348.2925
# Acceptance of random moves: 6.0 %, Temperature: 15.146576663612095
# Best score: 2322.2920, Worst score: 2582.6295, Mean score: 2467.1567
# Acceptance of random moves: 4.5 %, Temperature: 14.995110896975973
# Best score: 2116.0918, Worst score: 2478.6592, Mean score: 2265.4348
# Acceptance of random moves: 4.5 %, Temperature: 14.845159788006214
# Best score: 2078.7171, Worst score: 2259.1344, Mean score: 2167.8445
# Acceptance of random moves: 5.5 %, Temperature: 14.696708190126152
# Best score: 2099.8358, Worst score: 2393.5369, Mean score: 2229.9720
# Acceptance of random moves: 6.4 %, Temperature: 14.549741108224891
# Best score: 2219.7908, Worst score: 2640.2607, Mean score: 2420.2206
# Acceptance of random moves: 6.6 %, Temperature: 14.404243697142642
# Best score: 2241.9697, Worst score: 2480.9518, Mean score: 2343.9558
# Acceptance of random moves: 3.8 %, Temperature: 14.260201260171215
# Best score: 2049.1947, Worst score: 2503.2305, Mean score: 2255.7783
# Acceptance of random moves: 3.2 %, Temperature: 14.117599247569503
# Best score: 1959.1546, Worst score: 2291.4008, Mean score: 2071.5622
# Acceptance of random moves: 4.7 %, Temperature: 13.976423255093808
# Best score: 2089.3187, Worst score: 2330.8739, Mean score: 2207.0546
# Acceptance of random moves: 4.6 %, Temperature: 13.83665902254287
# Best score: 2063.8042, Worst score: 2311.0737, Mean score: 2202.2822
# Acceptance of random moves: 7.5 %, Temperature: 13.69829243231744
# Best score: 2140.6145, Worst score: 2435.6322, Mean score: 2244.1116
# Acceptance of random moves: 4.9 %, Temperature: 13.561309507994267
# Best score: 2127.2979, Worst score: 2451.3005, Mean score: 2257.6140
# Acceptance of random moves: 5.4 %, Temperature: 13.425696412914323
# Best score: 2094.9700, Worst score: 2394.6308, Mean score: 2205.7386
# Acceptance of random moves: 5.1 %, Temperature: 13.29143944878518
# Best score: 2015.9700, Worst score: 2244.1310, Mean score: 2135.3656
# Acceptance of random moves: 5.6 %, Temperature: 13.158525054297328
# Best score: 2004.9700, Worst score: 2201.9700, Mean score: 2068.1516
# Acceptance of random moves: 2.0 %, Temperature: 13.026939803754354
# Best score: 1938.9700, Worst score: 2075.1537, Mean score: 1985.4540
# Acceptance of random moves: 5.8 %, Temperature: 12.89667040571681
# Best score: 2007.9700, Worst score: 2346.0861, Mean score: 2155.3725
# Acceptance of random moves: 6.0 %, Temperature: 12.767703701659642
# Best score: 2149.5852, Worst score: 2367.8105, Mean score: 2251.7627
# Acceptance of random moves: 3.3 %, Temperature: 12.640026664643045
# Best score: 2061.0059, Worst score: 2315.8612, Mean score: 2190.8773
# Acceptance of random moves: 4.5 %, Temperature: 12.513626397996614
# Best score: 2030.0009, Worst score: 2368.0082, Mean score: 2216.6344
# Acceptance of random moves: 3.9 %, Temperature: 12.388490134016648
# Best score: 2106.6901, Worst score: 2344.9781, Mean score: 2258.8574
# Acceptance of random moves: 3.0 %, Temperature: 12.26460523267648
# Best score: 2017.0171, Worst score: 2280.2537, Mean score: 2098.6036
# Acceptance of random moves: 2.2 %, Temperature: 12.141959180349716
# Best score: 2020.8806, Worst score: 2126.4529, Mean score: 2062.7555
# Acceptance of random moves: 3.1 %, Temperature: 12.020539588546217
# Best score: 2023.7715, Worst score: 2258.8916, Mean score: 2142.5356
# Acceptance of random moves: 3.8 %, Temperature: 11.900334192660756
# Best score: 2047.4002, Worst score: 2324.4651, Mean score: 2131.8398
# Acceptance of random moves: 3.5 %, Temperature: 11.781330850734149
# Best score: 2058.7015, Worst score: 2283.1381, Mean score: 2156.9655
# Acceptance of random moves: 4.7 %, Temperature: 11.663517542226806
# Best score: 2022.4904, Worst score: 2215.0467, Mean score: 2094.4694
# Acceptance of random moves: 3.9 %, Temperature: 11.546882366804539
# Best score: 2034.2412, Worst score: 2280.6035, Mean score: 2118.9045
# Acceptance of random moves: 3.9 %, Temperature: 11.431413543136493
# Best score: 2007.3977, Worst score: 2219.8865, Mean score: 2111.5477
# Acceptance of random moves: 3.2 %, Temperature: 11.317099407705129
# Best score: 1994.7462, Worst score: 2241.0044, Mean score: 2097.3359
# Acceptance of random moves: 3.8 %, Temperature: 11.203928413628077
# Best score: 1963.4993, Worst score: 2281.7468, Mean score: 2155.8576
# Acceptance of random moves: 2.4 %, Temperature: 11.091889129491797
# Best score: 1878.2650, Worst score: 2020.6273, Mean score: 1954.9704
# Acceptance of random moves: 2.5 %, Temperature: 10.980970238196878
# Best score: 1863.6599, Worst score: 1999.2966, Mean score: 1930.2635
# Acceptance of random moves: 1.5 %, Temperature: 10.871160535814909
# Best score: 1813.0934, Worst score: 1928.1077, Mean score: 1857.4716
# Acceptance of random moves: 2.0 %, Temperature: 10.76244893045676
# Best score: 1753.8214, Worst score: 1921.9620, Mean score: 1828.7163
# Acceptance of random moves: 2.4 %, Temperature: 10.654824441152192
# Best score: 1757.9099, Worst score: 1997.0211, Mean score: 1891.5411
# Acceptance of random moves: 1.7 %, Temperature: 10.54827619674067
# Best score: 1870.1531, Worst score: 1995.1020, Mean score: 1933.5131
# Acceptance of random moves: 2.3 %, Temperature: 10.442793434773263
# Best score: 1893.5320, Worst score: 1994.1692, Mean score: 1946.6891
# Acceptance of random moves: 1.9 %, Temperature: 10.33836550042553
# Best score: 1894.9829, Worst score: 2014.2046, Mean score: 1945.1374
# Acceptance of random moves: 2.4 %, Temperature: 10.234981845421274
# Best score: 1896.3363, Worst score: 2059.3094, Mean score: 1975.7269
# Acceptance of random moves: 2.8 %, Temperature: 10.13263202696706
# Best score: 1902.6668, Worst score: 2051.0988, Mean score: 1979.4753
# Acceptance of random moves: 1.5 %, Temperature: 10.03130570669739
# Best score: 1861.6189, Worst score: 2056.5872, Mean score: 1936.2532
# Acceptance of random moves: 1.7 %, Temperature: 9.930992649630417
# Best score: 1878.0700, Worst score: 2001.1940, Mean score: 1909.5676
# Acceptance of random moves: 1.3 %, Temperature: 9.831682723134113
# Best score: 1884.8902, Worst score: 1966.3945, Mean score: 1913.3524
# Acceptance of random moves: 2.5 %, Temperature: 9.733365895902772
# Best score: 1905.1589, Worst score: 2107.1547, Mean score: 1973.9193
# Acceptance of random moves: 1.4 %, Temperature: 9.636032236943743
# Best score: 1970.7945, Worst score: 2058.0031, Mean score: 2015.8823
# Acceptance of random moves: 1.4 %, Temperature: 9.539671914574306
# Best score: 1929.8660, Worst score: 2041.8591, Mean score: 1965.0285
# Acceptance of random moves: 1.9 %, Temperature: 9.444275195428563
# Best score: 1940.4920, Worst score: 2084.1953, Mean score: 2011.1247
# Acceptance of random moves: 2.3 %, Temperature: 9.349832443474277
# Best score: 2008.6970, Worst score: 2121.4413, Mean score: 2057.4156
# Acceptance of random moves: 2.3 %, Temperature: 9.256334119039535
# Best score: 2020.0912, Worst score: 2150.0259, Mean score: 2086.5153
# Acceptance of random moves: 1.3 %, Temperature: 9.16377077784914
# Best score: 1939.9990, Worst score: 2064.7356, Mean score: 1977.3828
# Acceptance of random moves: 2.4 %, Temperature: 9.072133070070647
# Best score: 1890.0167, Worst score: 2019.0357, Mean score: 1960.6259
# Acceptance of random moves: 1.2 %, Temperature: 8.98141173936994
# Best score: 1852.3418, Worst score: 1960.7235, Mean score: 1894.6993
# Acceptance of random moves: 2.1 %, Temperature: 8.891597621976242
# Best score: 1852.3418, Worst score: 2004.7425, Mean score: 1942.3657
# Acceptance of random moves: 0.8 %, Temperature: 8.80268164575648
# Best score: 1826.1473, Worst score: 1887.1207, Mean score: 1852.9966
# Acceptance of random moves: 1.9 %, Temperature: 8.714654829298913
# Best score: 1882.6016, Worst score: 2015.9787, Mean score: 1940.5518
# Acceptance of random moves: 1.2 %, Temperature: 8.627508281005925
# Best score: 1813.9475, Worst score: 1921.3280, Mean score: 1858.1501
# Acceptance of random moves: 0.7 %, Temperature: 8.541233198195865
# Best score: 1796.5405, Worst score: 1840.6717, Mean score: 1817.7457
# Acceptance of random moves: 1.9 %, Temperature: 8.455820866213907
# Best score: 1813.4568, Worst score: 1969.6807, Mean score: 1883.3628
# Acceptance of random moves: 1.3 %, Temperature: 8.371262657551767
# Best score: 1779.8917, Worst score: 1991.1568, Mean score: 1902.4094
# Acceptance of random moves: 2.4 %, Temperature: 8.28755003097625
# Best score: 1780.0194, Worst score: 1922.9402, Mean score: 1838.6625
# Acceptance of random moves: 1.5 %, Temperature: 8.204674530666487
# Best score: 1866.7103, Worst score: 1937.6403, Mean score: 1887.3858
# Acceptance of random moves: 1.6 %, Temperature: 8.122627785359823
# Best score: 1886.8030, Worst score: 2008.8967, Mean score: 1949.8050
# Acceptance of random moves: 1.1 %, Temperature: 8.041401507506224
# Best score: 1827.4739, Worst score: 1989.7929, Mean score: 1886.6075
# Acceptance of random moves: 0.9 %, Temperature: 7.960987492431162
# Best score: 1834.3247, Worst score: 1887.5976, Mean score: 1854.8229
# Acceptance of random moves: 1.3 %, Temperature: 7.881377617506851
# Best score: 1863.8012, Worst score: 1936.1160, Mean score: 1891.5887
# Acceptance of random moves: 0.5 %, Temperature: 7.802563841331782
# Best score: 1828.1898, Worst score: 1891.1306, Mean score: 1872.4163
# Acceptance of random moves: 1.1 %, Temperature: 7.724538202918464
# Best score: 1796.6303, Worst score: 1867.3632, Mean score: 1826.7152
# Acceptance of random moves: 1.5 %, Temperature: 7.647292820889279
# Best score: 1796.5247, Worst score: 1881.3369, Mean score: 1839.7723
# Acceptance of random moves: 0.5 %, Temperature: 7.570819892680387
# Best score: 1753.7995, Worst score: 1898.5197, Mean score: 1782.1944
# Acceptance of random moves: 0.6 %, Temperature: 7.495111693753583
# Best score: 1739.1208, Worst score: 1770.1980, Mean score: 1760.6095
# Acceptance of random moves: 1.4 %, Temperature: 7.4201605768160475
# Best score: 1730.0462, Worst score: 1817.6026, Mean score: 1761.2197
# Acceptance of random moves: 1.4 %, Temperature: 7.345958971047887
# Best score: 1788.8051, Worst score: 1850.6138, Mean score: 1814.1056
# Acceptance of random moves: 0.8 %, Temperature: 7.272499381337408
# Best score: 1770.0816, Worst score: 1850.6138, Mean score: 1800.0848
# Acceptance of random moves: 1.0 %, Temperature: 7.199774387524034
# Best score: 1694.9932, Worst score: 1782.1416, Mean score: 1721.8552
# Acceptance of random moves: 0.7 %, Temperature: 7.127776643648794
# Best score: 1738.3128, Worst score: 1787.6434, Mean score: 1763.6991
# Acceptance of random moves: 1.1 %, Temperature: 7.056498877212306
# Best score: 1746.5293, Worst score: 1836.8897, Mean score: 1787.2233
# Acceptance of random moves: 1.1 %, Temperature: 6.985933888440183
# Best score: 1764.0864, Worst score: 1864.0630, Mean score: 1827.0543
# Acceptance of random moves: 0.8 %, Temperature: 6.916074549555781
# Best score: 1744.1757, Worst score: 1776.0008, Mean score: 1763.4132
# Acceptance of random moves: 0.4 %, Temperature: 6.8469138040602235
# Best score: 1755.0400, Worst score: 1788.4079, Mean score: 1767.3790
# Acceptance of random moves: 0.9 %, Temperature: 6.778444666019621
# Best score: 1752.1171, Worst score: 1788.3018, Mean score: 1776.1226
# Acceptance of random moves: 0.8 %, Temperature: 6.710660219359425
# Best score: 1745.0221, Worst score: 1776.1936, Mean score: 1764.1456
# Acceptance of random moves: 0.9 %, Temperature: 6.64355361716583
# Best score: 1746.0370, Worst score: 1845.6381, Mean score: 1782.6650
# Acceptance of random moves: 0.6 %, Temperature: 6.577118080994172
# Best score: 1794.1891, Worst score: 1870.4135, Mean score: 1830.2197
# Acceptance of random moves: 0.8 %, Temperature: 6.51134690018423
# Best score: 1755.1281, Worst score: 1796.9180, Mean score: 1769.8469
# Acceptance of random moves: 0.6 %, Temperature: 6.446233431182388
# Best score: 1716.3545, Worst score: 1772.0338, Mean score: 1747.2220
# Acceptance of random moves: 0.6 %, Temperature: 6.381771096870564
# Best score: 1676.0053, Worst score: 1745.0558, Mean score: 1698.4989
# Acceptance of random moves: 0.3 %, Temperature: 6.317953385901858
# Best score: 1680.0062, Worst score: 1692.0209, Mean score: 1687.0294
# Acceptance of random moves: 0.5 %, Temperature: 6.25477385204284
# Best score: 1678.0401, Worst score: 1703.0011, Mean score: 1693.3080
# Acceptance of random moves: 0.4 %, Temperature: 6.192226113522412
# Best score: 1661.0079, Worst score: 1733.0145, Mean score: 1694.0809
# Acceptance of random moves: 0.3 %, Temperature: 6.130303852387187
# Best score: 1661.0079, Worst score: 1677.0975, Mean score: 1666.5848
# Acceptance of random moves: 0.0 %, Temperature: 6.069000813863315
# Best score: 1646.0279, Worst score: 1666.0359, Mean score: 1651.9401
# Acceptance of random moves: 0.7 %, Temperature: 6.008310805724682
# Best score: 1646.0279, Worst score: 1683.1334, Mean score: 1665.9177
# Acceptance of random moves: 0.3 %, Temperature: 5.948227697667435
# Best score: 1632.4713, Worst score: 1668.7713, Mean score: 1649.8647
# Acceptance of random moves: 0.8 %, Temperature: 5.888745420690761
# Best score: 1633.9092, Worst score: 1657.3631, Mean score: 1647.7499
# Acceptance of random moves: 0.6 %, Temperature: 5.829857966483853
# Best score: 1628.5703, Worst score: 1650.6877, Mean score: 1637.1135
# Acceptance of random moves: 1.0 %, Temperature: 5.771559386819014
# Best score: 1593.9057, Worst score: 1659.8589, Mean score: 1623.7941
# Acceptance of random moves: 0.4 %, Temperature: 5.713843792950824
# Best score: 1587.1526, Worst score: 1615.0048, Mean score: 1592.8608
# Acceptance of random moves: 0.4 %, Temperature: 5.656705355021316
# Best score: 1597.7683, Worst score: 1622.4959, Mean score: 1609.6362
# Acceptance of random moves: 0.7 %, Temperature: 5.600138301471103
# Best score: 1570.0297, Worst score: 1608.6510, Mean score: 1588.7790
# Acceptance of random moves: 0.4 %, Temperature: 5.544136918456392
# Best score: 1578.9401, Worst score: 1601.4689, Mean score: 1586.0121
# Acceptance of random moves: 0.8 %, Temperature: 5.488695549271828
# Best score: 1562.9708, Worst score: 1631.3509, Mean score: 1588.9571
# Acceptance of random moves: 0.3 %, Temperature: 5.433808593779109
# Best score: 1512.1878, Worst score: 1587.4590, Mean score: 1565.3684
# Acceptance of random moves: 0.1 %, Temperature: 5.379470507841318
# Best score: 1512.1878, Worst score: 1513.1523, Mean score: 1512.8234
# Done: runtime=923.87s, objective=1513.1523, Jain=0.9556

# %%
# Load CSV
df = pd.read_csv("misc/sa_grid_search_results.csv")

# Plot objective function as scatter over the grid
plt.figure(figsize=(8, 6))
plt.scatter(df["T_init"], df["alpha"], s=150, c=df["final_objective"])
plt.colorbar(label="Final Objective Value")

plt.xlabel("T_init")
plt.ylabel("alpha")
plt.title("Simulated Annealing Grid Search – Objective Function")
plt.grid(True, linestyle="--", alpha=0.4)

plt.show()

# %%
# Plot runtime
plt.figure(figsize=(8,5))
plt.scatter(range(len(df)), df["runtime_sec"])
plt.xticks(range(len(df)), df["T_init"].astype(str) + ", " + df["alpha"].astype(str), rotation=90)
plt.ylabel("Runtime (seconds)")
plt.title("Simulated Annealing Runtime Across Parameter Grid")

plt.tight_layout()
plt.show()

# %%
df_clean = df[~((df["T_init"] == 20) & (df["alpha"] == 0.98))]
plt.figure(figsize=(8,5))
plt.scatter(range(len(df_clean)), df_clean["runtime_sec"])
plt.xticks(range(len(df_clean)), df_clean["T_init"].astype(str) + ", " + df_clean["alpha"].astype(str), rotation=90)
plt.ylabel("Runtime (seconds)")
plt.title("Simulated Annealing Runtime Across Parameter Grid, outlier removed")
# Out:
# Text(0.5, 1.0, 'Simulated Annealing Runtime Across Parameter Grid, outlier removed')

# %% [markdown]
# ## Subtask 11: More experiments
# The problem is, the instances in the different folders have all widely differnet gamma values, so it does not really make sense to compare them. Let's instead compare the instances for fixed n with varying gamma. So let's chose n = 100 and test our instances for varying gammas. You can easily change the algorithm in the folliwng code to test different alogrithms, I didn't do it in different cells after each other in order not to bloat the notebook.

# %%
    folder = f"instances/1000/test" # change folder to test differnt n's
    files = glob.glob(os.path.join(folder, "*.txt"))
    files.sort()
    rows = []

    for file in files:
        instance = Instance(file)
        start_time = time.time()
        solution = randomized_nearest_neighbor_heuristic(instance, 0.5)
        runtime = time.time() - start_time

        rows.append({
            "n": instance.n,
            "gamma": instance.gamma,
            "objective": objective_function(instance, solution),
            "runtime": runtime
        })

    df = pd.DataFrame(rows)
    df.to_csv("results_100.csv", index=False)

# %%
df = pd.read_csv("misc/results_100.csv")

# --- Plot: Gamma vs Runtime ---
plt.figure(figsize=(8, 5))
plt.scatter(df["gamma"], df["runtime"])
plt.xlabel("Gamma")
plt.ylabel("Runtime (seconds)")
plt.title("Gamma vs Runtime")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Plot: Gamma vs Objective Function ---
plt.figure(figsize=(8, 5))
plt.scatter(df["gamma"], df["objective"])
plt.xlabel("Gamma")
plt.ylabel("Objective Function Value")
plt.title("Gamma vs Objective Function")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Creating the solution files
# Now we actually want to create solution files we can submit to tuwel

# %%
def save_solution(instance_file_path, routes, output_dir="solutions"):
    os.makedirs(output_dir, exist_ok=True)

    # extract instance name
    instance_name = os.path.splitext(os.path.basename(instance_file_path))[0]

    # prepare output file path
    out_file = os.path.join(output_dir, instance_name + "_solution.txt")

    with open(out_file, "w") as f:
        # first line: instance name
        f.write(instance_name + "\n")

        # then each vehicle route, request indices separated with spaces
        for route in routes:
            # route is something like [1, 11, 2, 3, 13, ...]
            line = " ".join(str(r) for r in route)
            f.write(line + "\n")

    print(f"Saved solution to {out_file}")

# %%
def solution_pipeline(file):
    instance = Instance(file)

    # Deterministic Construction Heuristc
    solution = nearest_neighbor_heuristic(instance)
    print(f"Nearest neighbor construction heuristic achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_deterministic_construction_heuristic")

    # Beam search
    solution = beam_search(instance, 50)
    initial_solution = solution
    print(f"beam search achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_beam_search")

    # Local search
    solution = local_search(instance, initial_solution, RelocateFlexible(instance), best_improvement, 250)
    print(f"local search achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_local_search")

    # VND
    neighborhoods = [
        DelayDropoffs(instance),
        AdvancePickups(instance),
        RelocateCompact(instance),
        RelocateFlexible(instance),
        ReplaceWithUnserved(instance),
    ]
    solution = variable_neighborhood_descent(State.from_routes(instance, initial_solution), neighborhoods, step_fn=best_improvement, max_iter=50)
    print(f"VND achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_VND")

    # GRASP
    solution = GRASP(instance)
    print(f"GRASP achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_GRASP")

    # SA
    solution = simulated_annealing(instance, routes, 15, alpha = 0.95, max_it=20)
    print(f"SA achieves a score of: {objective_function(instance, solution)}")
    save_solution(file, solution, "solutions/solutions_SA")

# %%
solution_pipeline("instances/100/competition/instance61_nreq100_nveh2_gamma91.txt")
# Out:
# Nearest neighbor construction heuristic achieves a score of: 5045.017549591446
# Saved solution to solutions_deterministic_construction_heuristic/instance61_nreq100_nveh2_gamma91_solution.txt

# %%
# Lets generate a solution
relevant_files = ["instances/100/competition/instance61_nreq100_nveh2_gamma91.txt",  "instances/1000/competition/instance61_nreq1000_nveh20_gamma879.txt","instances/2000/competition/instance61_nreq2000_nveh40_gamma1829.txt"]
for file in relevant_files:
    solution_pipeline(file)
# Out:
# Nearest neighbor construction heuristic achieves a score of: 5045.017549591446
# Saved solution to solutions_deterministic_construction_heuristic/instance61_nreq100_nveh2_gamma91_solution.txt
# beam search achieves a score of: 3821.7317828479413
# Saved solution to solutions_beam_search/instance61_nreq100_nveh2_gamma91_solution.txt
# ran 7 iterations
# local search achieves a score of: 3733.101279260549
# Saved solution to solutions_local_search/instance61_nreq100_nveh2_gamma91_solution.txt
